# %%
import sys
sys.path.append('../../pybeh')
import warnings
warnings.simplefilter('ignore')
import pandas as pd
import numpy as np
import cmlreaders as cml
from SimulatedSubjectData import *
from pandas_to_pybeh import pd_crp, get_all_matrices
import matplotlib.pyplot as plt
import pickle
pd.set_option("display.max_columns", None)
import os
import cmldask.CMLDask as da
import cmldask
from dask.distributed import wait, as_completed, progress
from dask import delayed, compute
import logging
import glob

# %%
list_len = 15
num_lists = 1000

exp = 'CourierReinstate1'
subjects = ['LTP564', 'LTP565', 'LTP566', 'LTP567', 'LTP568', 'LTP569', 'LTP571', 'LTP572', 'LTP573',
            'LTP574', 'LTP575', 'LTP576', 'LTP577', 'LTP578', 'LTP579', 'LTP580', 'LTP581', 'LTP583',
            'LTP584', 'LTP585', 'LTP586', 'LTP587', 'LTP588', 'LTP589', 'LTP590', 'LTP591', 'LTP592', 
            'LTP593', 'LTP594', 'LTP595', 'LTP596', 'LTP597', 'LTP598', 'LTP599', 'LTP600', 'LTP601', 
            'LTP602', 'LTP603', 'LTP604', 'LTP605']

# %%
def save_data(data, filename):
    with open(filename, 'wb') as f:
        pickle.dump(data, f, protocol=pickle.HIGHEST_PROTOCOL)
    print(f"Dictionary saved to {filename}")

def load_data(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# %%
df = cml.get_data_index('ltp', rootdir='/').query("experiment == @exp")

full_evs = None
for i, row in df.iterrows():
    reader = cml.CMLReader(subject=row['subject'], experiment=row['experiment'], session=row['session'])
    evs = reader.load('task_events')
    full_evs = evs if full_evs is None else pd.concat([full_evs, evs], ignore_index=True)
full_evs = full_evs.query("subject in @subjects")
full_evs = full_evs[(full_evs['item'] != "AMPLIFIER") & (full_evs['item'] != "APPLE") & (full_evs['item'] != "AXE") & 
                    (full_evs['item'] != "BASKETBALL_HOOP") & (full_evs['item'] != "DOOR") & (full_evs['item'] != "IRONING_BOARD") & 
                    (full_evs['item'] != "SHOVEL") & (full_evs['item'] != "STOVE")]

# %%
with open("words.pkl", "rb") as f:
    wordpool = pickle.load(f)

# %%
def compute_recall_rate(data):
    word_evs = data[data['type'] == 'WORD']
    return word_evs['recalled'].sum() / len(word_evs)

def compute_first_recall(data, list_len):
    rec_evs = data[data['type'] == 'REC_WORD']
    rec_evs['pos'] = rec_evs.groupby(['session', 'trial']).cumcount()
    first_recall_df = rec_evs.query('pos == 0 and serialpos >= 0')
    first_recall_df = first_recall_df.groupby(
        ['serialpos']).agg(
        {'recalled': 'count'}).reindex(range(1, list_len+1), fill_value=0)
    n_lists = first_recall_df['recalled'].sum()
    return first_recall_df['recalled'].to_numpy(dtype=float) / n_lists

def compute_lag_crp_single_subject_array(
    data, 
    list_len
):
    center = list_len - 1
    min_lag = -center
    max_lag = center + 1
    actual = {lag: 0 for lag in range(min_lag, max_lag)}
    possible = {lag: 0 for lag in range(min_lag, max_lag)}
    for session_id, session_data in data.groupby('session'):
        recalls = session_data[session_data.type == 'REC_WORD']
        # print(recalls)
        words = session_data[session_data.type == 'WORD']
        if recalls.empty or words.empty:
            print(f"session {session_id} has no events")
            continue
        # print(recalls.intruded)
        recalls = recalls[(recalls['trial'] != -999)]
        word_to_pos = dict(zip(words['item'], words['serialpos']))
        # print(word_to_pos)
        # print(recalls)
        for trial in recalls['trial'].unique():
            trial_words = words[words['trial'] == trial]['item'].tolist()
            trial_recalls = (recalls[recalls['trial'] == trial]
                             .sort_values('rectime')
                             .drop_duplicates('item'))
            
            if len(trial_recalls) < 2:
                print(f"session {session_id}, trial {trial} doesn't have enough events")
                continue
            trial_recalls = trial_recalls[trial_recalls['item'].isin(trial_words)]
            recall_pos = [word_to_pos[w] for w in trial_recalls['item']]
            # print(recall_pos)
            for i, cur in enumerate(recall_pos[:-1]):
                lag = recall_pos[i+1] - cur
                if min_lag <= lag <= max_lag and lag != 0:
                    actual[lag] += 1
                for pos in set(range(1, list_len+1)) - set(recall_pos[:i+1]):
                    pl = pos - cur
                    if min_lag <= pl <= max_lag and pl != 0:
                        possible[pl] += 1

    # build CRP array
    full_len = 2*list_len - 1
    crp = np.full(full_len, np.nan)
    center = list_len - 1
    for lag in range(min_lag, max_lag):
        idx = center + lag
        if 0 <= idx < full_len:
            crp[idx] = (actual[lag] / possible[lag]) if possible[lag] > 0 else np.nan
    crp[center] = 0.0
    return crp

# %%
df595 = full_evs[full_evs['subject'] == 'LTP595']
# compute_recall_rate(df595)
# compute_first_recall(df595, list_len)
crp595 = compute_lag_crp_single_subject_array(df595, list_len)
crp595
# Out:
# array([0.06382979, 0.05882353, 0.04424779, 0.02898551, 0.06470588,
#        0.04102564, 0.05479452, 0.04979253, 0.07806691, 0.04895105,
#        0.06644518, 0.08196721, 0.14195584, 0.3250774 , 0.        ,
#        0.45721271, 0.20478723, 0.10670732, 0.06713781, 0.06477733,
#        0.06161137, 0.0483871 , 0.03870968, 0.02459016, 0.04081633,
#        0.05263158, 0.04081633, 0.        , 0.        ])

# %%
# CourierReinstate1 data
sub_parameters = {}

for sub in subjects:
    df_sub = full_evs[full_evs['subject'] == sub]
    recall_rate = compute_recall_rate(df_sub)
    first_recall = compute_first_recall(df_sub, list_len)
    lag_crp = compute_lag_crp_single_subject_array(df_sub, list_len)
    sub_parameters[sub] = {
        'recall_rate': recall_rate,
        'first_recall': first_recall,
        'lag_crp': lag_crp
    }
# Out:
# session 2, trial 7 doesn't have enough events

# %%
import optuna
import numpy as np

def crp_loss(simulated_crp, target_crp):
    mask = ~np.isnan(simulated_crp) & ~np.isnan(target_crp)
    return np.mean((simulated_crp[mask] - target_crp[mask])**2)

def make_objective(sub_id, sub_parameters, target_crp, list_len, num_lists, wordpool, n_avg=3):
    
    def objective(trial):
        # Suggest lag_crp distribution for this subject
        lag_crp = np.array([
            trial.suggest_float(f"lag_{i}", 1e-6, 1.0)
            for i in range(len(target_crp))
        ])
        lag_crp /= lag_crp.sum()  # normalize
        # print(lag_crp)
        # Pull subject parameters
        recall_rate = sub_parameters[sub_id]['recall_rate']
        first_recall = sub_parameters[sub_id]['first_recall']

        losses = []
        for _ in range(n_avg):
            sim = SimulatedSubjectData(
                subject=sub_id,
                first_recall=first_recall,
                lag_crp=lag_crp,
                recall_rate=recall_rate,
                value_acc=0.6,     # if you use this, add to sub_parameters
                complex_params=None,     # same here
                seed=None
            )
            df = sim.generateData(list_len, num_lists, num_lists_per_sess=10, wordpool=wordpool, gen_pos=True)
            sim_crp = compute_lag_crp_single_subject_array(df, list_len)
            losses.append(crp_loss(sim_crp, target_crp))

        return np.mean(losses)
    return objective

# %%
def early_stop_callback(study, trial):
    # stop if best loss hasn't improved in the last N trials
    if len(study.trials) > 10:  # require minimum trials first
        recent_losses = [t.value for t in study.trials[-10:] if t.value is not None]
        if max(recent_losses) - min(recent_losses) < 1e-4:  # threshold
            print("Convergence reached, stopping early")
            study.stop()

# %%
# # Example: pick a subject
# sub_id = subjects[0]
# target_crp = sub_parameters[sub_id]['lag_crp']  # empirical CRP

# # Create Optuna study
# study = optuna.create_study(direction="minimize")
# objective = make_objective(sub_id, sub_parameters, target_crp, list_len=15, num_lists=30, wordpool=wordpool, n_avg=5)
# study.optimize(objective, n_trials=100, callbacks=[early_stop_callback])

# print("Best loss:", study.best_value)

# best_lag_crp = np.array([study.best_params[f"lag_{i}"] for i in range(len(target_crp))])
# best_lag_crp /= best_lag_crp.sum()
# print("Best lag_crp distribution:", best_lag_crp)

# %%
# Configure logging at the top of your notebook/script
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s [%(levelname)s] %(message)s'
)
logger = logging.getLogger(__name__)

# set up slurm 
logdir = os.path.join(os.path.abspath(os.curdir), 'dask_appendix_logs')
# first_run = False
dask_args = {'job_name': "zrentala_workshop4", 'memory_per_job': "10GB", 'max_n_jobs': 20,
             'log_directory': './results/Assignment_8/cluster_logs'}
os.makedirs(dask_args['log_directory'], exist_ok=True)
client = da.new_dask_client(**dask_args)
# Out:
# Unique port for zrentala is 51618
# {'dashboard_address': ':51618'}
# To view the dashboard, run:
# `ssh -fN zrentala@rhino2.psych.upenn.edu -L 8000:192.168.86.101:51618` in your local computer's terminal (NOT rhino)
# and then navigate to localhost:8000 in your browser

# %%
def optimize_subject(folder, subject, sub_parameters, obj_params, wordpool):
    logger.info(f"Processing {subject}")
    list_len = obj_params['list_len']
    num_lists = obj_params['num_lists']
    n_avg = obj_params['n_avg']

    target_crp = sub_parameters[subject]['lag_crp']
    study = optuna.create_study(direction="minimize")
    objective = make_objective(subject, sub_parameters, target_crp, list_len=list_len, num_lists=num_lists, wordpool=wordpool, n_avg=n_avg)
    study.optimize(objective, n_trials=100, callbacks=[early_stop_callback])

    best_lag_crp = np.array([study.best_params[f"lag_{i}"] for i in range(len(target_crp))])
    best_lag_crp /= best_lag_crp.sum()

    results[subject] = {
        "best_loss": study.best_value,
        "best_lag_crp": best_lag_crp
    }
    
    save_data(results, f'{folder}/{subject}_optimized.pkl')
    
    return results

# %%
results = {}
folder = 'Optimization_Results'
subj_list = subjects
sub_params = sub_parameters
obj_params ={'list_len': 15, 'num_lists': 100, 'n_avg':5}
overwrite = False

if overwrite:
    if not os.path.exists(folder):
        os.makedirs(folder)

    delayed_results = [delayed(optimize_subject)(folder, subj, sub_params, obj_params,wordpool) for subj in subj_list]
    results = compute(*delayed_results)

# %%
def load_all_subjects_optimized(folder):
    """
    Loads all {subject}_optimized.pkl files in the folder and combines them into a single dictionary.
    """
    all_data = {}
    # find all files ending with _optimized.pkl
    files = glob.glob(os.path.join(folder, "*_optimized.pkl"))
    
    for file in files:
        with open(file, 'rb') as f:
            subject_data = pickle.load(f)  # this is a single dict like {'LTP564': {...}}
            # merge into all_data
            all_data.update(subject_data)
    
    return all_data

# %%
subj_optimized= load_all_subjects_optimized(folder)

# %%
# Simulated data
len_lists = 15
num_lists = 100
sim_dfs = {}

for sub, parameters in sub_parameters.items():
    best_lag_crp = subj_optimized[sub]['best_lag_crp']
    # print(best_lag_crp)
    sim = SimulatedSubjectData(
        subject=sub,
        first_recall=parameters['first_recall'],
        lag_crp=best_lag_crp,
        recall_rate=parameters['recall_rate'],
        value_acc=0.6
    )
    df_sim = sim.generateData(list_len, num_lists, wordpool=wordpool, gen_pos=True)
    # print(df_sim)
    sim_dfs[sub] = df_sim
# Out:
#      experiment            item  item_val  trial  rectime  recalled  \
# 0         VCsim          lotion         8      0        0         1
# 1         VCsim       mouthwash         0      0       -1         0
# 2         VCsim       lollipops         9      0       -1         0
# 3         VCsim          fabric        13      0        0         1
# 4         VCsim  protein_shakes        15      0        0         1
# ...         ...             ...       ...    ...      ...       ...
# 2503      VCsim         hangers         4     99       99         1
# 2504      VCsim         hangers         4     99       99         1
# 2505      VCsim           drill        10     99       99         1
# 2506      VCsim       croissant        17     99       99         1
# 2507      VCsim         peonies        18     99       99         1
#
#       recallpos  serialpos subject      type  val_list_avg  val_guess  \
# 0             3          1  LTP564      WORD      9.600000         14
# 1            -1          2  LTP564      WORD      9.600000         14
# 2            -1          3  LTP564      WORD      9.600000         14
# 3             7          4  LTP564      WORD      9.600000         14
# 4             9          5  LTP564      WORD      9.600000         14
# ...         ...        ...     ...       ...           ...        ...
# 2503         10         11  LTP564  REC_WORD      9.466667         10
# 2504         10         11  LTP564  REC_WORD      9.466667         10
# 2505          3         13  LTP564  REC_WORD      9.466667         10
# 2506          5         14  LTP564  REC_WORD      9.466667         10
# 2507          1         15  LTP564  REC_WORD      9.466667         10
#
#          pos_x     pos_y  session
# 0     0.316644  0.119676        0
# 1     0.019815  0.557175        0
# 2     0.982571  0.356876        0
# 3     0.394905  0.096101        0
# 4     0.139883  0.268164        0
# ...        ...       ...      ...
# 2503  0.435593  0.473104        9
# 2504  0.435593  0.473104        9
# 2505  0.100698  0.355430        9
# 2506  0.694419  0.405207        9
# 2507  0.336990  0.894351        9
#
# [2508 rows x 15 columns]
#      experiment           item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim           pots        11      0        0         1          1
# 1         VCsim         cereal         9      0       -1         0         -1
# 2         VCsim          legos         5      0       -1         0         -1
# 3         VCsim        cookies        15      0       -1         0         -1
# 4         VCsim         pliers         7      0        0         1         11
# ...         ...            ...       ...    ...      ...       ...        ...
# 2706      VCsim       dumbells        18     99       99         1          8
# 2707      VCsim    baking_soda         0     99       99         1         10
# 2708      VCsim    screwdriver         6     99       99         1          5
# 2709      VCsim  hot_chocolate         8     99       99         1          7
# 2710      VCsim           cups        19     99       99         1          1
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP565      WORD      7.200000         10  0.592034
# 1             2  LTP565      WORD      7.200000         10  0.287896
# 2             3  LTP565      WORD      7.200000         10  0.686933
# 3             4  LTP565      WORD      7.200000         10  0.673778
# 4             5  LTP565      WORD      7.200000         10  0.002189
# ...         ...     ...       ...           ...        ...       ...
# 2706         11  LTP565  REC_WORD      8.333333         12  0.754979
# 2707         12  LTP565  REC_WORD      8.333333         12  0.072663
# 2708         13  LTP565  REC_WORD      8.333333         12  0.055948
# 2709         14  LTP565  REC_WORD      8.333333         12  0.177125
# 2710         15  LTP565  REC_WORD      8.333333         12  0.448665
#
#          pos_y  session
# 0     0.182653        0
# 1     0.250179        0
# 2     0.210526        0
# 3     0.857408        0
# 4     0.950466        0
# ...        ...      ...
# 2706  0.384990        9
# 2707  0.879912        9
# 2708  0.563001        9
# 2709  0.070303        9
# 2710  0.960383        9
#
# [2711 rows x 15 columns]
#      experiment             item  item_val  trial  rectime  recalled  \
# 0         VCsim  training_wheels         9      0       -1         0
# 1         VCsim     watering_can         2      0       -1         0
# 2         VCsim              cat        13      0        0         1
# 3         VCsim         amethyst        12      0        0         1
# 4         VCsim             bird        14      0        0         1
# ...         ...              ...       ...    ...      ...       ...
# 2514      VCsim            nails         7     99       99         1
# 2515      VCsim            paint         6     99       99         1
# 2516      VCsim        jump_rope        15     99       99         1
# 2517      VCsim            cream         5     99       99         1
# 2518      VCsim            flute        11     99       99         1
#
#       recallpos  serialpos subject      type  val_list_avg  val_guess  \
# 0            -1          1  LTP566      WORD      9.733333         13
# 1            -1          2  LTP566      WORD      9.733333         13
# 2             3          3  LTP566      WORD      9.733333         13
# 3             2          4  LTP566      WORD      9.733333         13
# 4             8          5  LTP566      WORD      9.733333         13
# ...         ...        ...     ...       ...           ...        ...
# 2514          2         10  LTP566  REC_WORD      7.933333          8
# 2515         13         11  LTP566  REC_WORD      7.933333          8
# 2516          1         12  LTP566  REC_WORD      7.933333          8
# 2517          7         14  LTP566  REC_WORD      7.933333          8
# 2518          6         15  LTP566  REC_WORD      7.933333          8
#
#          pos_x     pos_y  session
# 0     0.406791  0.214988        0
# 1     0.553836  0.923811        0
# 2     0.706372  0.204127        0
# 3     0.046557  0.817675        0
# 4     0.716083  0.282509        0
# ...        ...       ...      ...
# 2514  0.366191  0.360729        9
# 2515  0.048751  0.043586        9
# 2516  0.102296  0.300443        9
# 2517  0.558037  0.995014        9
# 2518  0.010862  0.076277        9
#
# [2519 rows x 15 columns]
#      experiment       item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim       bass        11      0       -1         0         -1
# 1         VCsim     q-tips         0      0       -1         0         -1
# 2         VCsim     mirror        16      0       -1         0         -1
# 3         VCsim      bread        18      0       -1         0         -1
# 4         VCsim       yarn         8      0        0         1          4
# ...         ...        ...       ...    ...      ...       ...        ...
# 2292      VCsim      locks        10     99       99         1          6
# 2293      VCsim    oatmeal         6     99       99         1          3
# 2294      VCsim     lotion         5     99       99         1          5
# 2295      VCsim  water_gun         9     99       99         1          4
# 2296      VCsim      scale        11     99       99         1          1
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP567      WORD      9.200000          9  0.762161
# 1             2  LTP567      WORD      9.200000          9  0.637493
# 2             3  LTP567      WORD      9.200000          9  0.066286
# 3             4  LTP567      WORD      9.200000          9  0.875047
# 4             5  LTP567      WORD      9.200000          9  0.009989
# ...         ...     ...       ...           ...        ...       ...
# 2292          6  LTP567  REC_WORD      7.533333          7  0.931252
# 2293          8  LTP567  REC_WORD      7.533333          7  0.693569
# 2294         13  LTP567  REC_WORD      7.533333          7  0.741996
# 2295         14  LTP567  REC_WORD      7.533333          7  0.088958
# 2296         15  LTP567  REC_WORD      7.533333          7  0.746024
#
#          pos_y  session
# 0     0.680838        0
# 1     0.664889        0
# 2     0.666061        0
# 3     0.334931        0
# 4     0.892016        0
# ...        ...      ...
# 2292  0.891455        9
# 2293  0.874086        9
# 2294  0.813999        9
# 2295  0.033525        9
# 2296  0.214982        9
#
# [2297 rows x 15 columns]
#      experiment             item  item_val  trial  rectime  recalled  \
# 0         VCsim     curling_iron        14      0       -1         0
# 1         VCsim  training_wheels        13      0       -1         0
# 2         VCsim       hair_spray         7      0       -1         0
# 3         VCsim             gold         9      0        0         1
# 4         VCsim           ribbon         1      0       -1         0
# ...         ...              ...       ...    ...      ...       ...
# 2124      VCsim          daisies         6     99       99         1
# 2125      VCsim            drill         3     99       99         1
# 2126      VCsim          puppets         1     99       99         1
# 2127      VCsim            rings        19     99       99         1
# 2128      VCsim           cereal        17     99       99         1
#
#       recallpos  serialpos subject      type  val_list_avg  val_guess  \
# 0            -1          1  LTP568      WORD     10.466667         14
# 1            -1          2  LTP568      WORD     10.466667         14
# 2            -1          3  LTP568      WORD     10.466667         14
# 3             1          4  LTP568      WORD     10.466667         14
# 4            -1          5  LTP568      WORD     10.466667         14
# ...         ...        ...     ...       ...           ...        ...
# 2124          1          4  LTP568  REC_WORD      9.400000         12
# 2125          7          9  LTP568  REC_WORD      9.400000         12
# 2126          6         10  LTP568  REC_WORD      9.400000         12
# 2127          2         11  LTP568  REC_WORD      9.400000         12
# 2128          3         13  LTP568  REC_WORD      9.400000         12
#
#          pos_x     pos_y  session
# 0     0.427406  0.119815        0
# 1     0.676701  0.401211        0
# 2     0.015619  0.226726        0
# 3     0.389402  0.716752        0
# 4     0.557973  0.223149        0
# ...        ...       ...      ...
# 2124  0.389402  0.716752        9
# 2125  0.455978  0.771939        9
# 2126  0.098117  0.505364        9
# 2127  0.404757  0.295642        9
# 2128  0.780496  0.109009        9
#
# [2129 rows x 15 columns]
#      experiment           item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim    screwdriver         2      0       -1         0         -1
# 1         VCsim        muffins         6      0       -1         0         -1
# 2         VCsim           comb         8      0        0         1          1
# 3         VCsim  shaving_cream         6      0       -1         0         -1
# 4         VCsim         straws         5      0       -1         0         -1
# ...         ...            ...       ...    ...      ...       ...        ...
# 2047      VCsim         garlic         1     99       99         1          6
# 2048      VCsim   baseball_bat         9     99       99         1          2
# 2049      VCsim        oregano         2     99       99         1          5
# 2050      VCsim      kickboard         0     99       99         1          3
# 2051      VCsim         breaks        18     99       99         1          1
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP569      WORD           8.0         15  0.066148
# 1             2  LTP569      WORD           8.0         15  0.873859
# 2             3  LTP569      WORD           8.0         15  0.879750
# 3             4  LTP569      WORD           8.0         15  0.868319
# 4             5  LTP569      WORD           8.0         15  0.649234
# ...         ...     ...       ...           ...        ...       ...
# 2047          2  LTP569  REC_WORD           9.0          8  0.873859
# 2048          4  LTP569  REC_WORD           9.0          8  0.868319
# 2049          9  LTP569  REC_WORD           9.0          8  0.451839
# 2050         11  LTP569  REC_WORD           9.0          8  0.309642
# 2051         14  LTP569  REC_WORD           9.0          8  0.712491
#
#          pos_y  session
# 0     0.181307        0
# 1     0.424417        0
# 2     0.272553        0
# 3     0.046390        0
# 4     0.996042        0
# ...        ...      ...
# 2047  0.424417        9
# 2048  0.046390        9
# 2049  0.980059        9
# 2050  0.256795        9
# 2051  0.886748        9
#
# [2052 rows x 15 columns]
#      experiment       item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim      chain        12      0       -1         0         -1
# 1         VCsim      sugar         4      0        0         1          1
# 2         VCsim    puppets        16      0       -1         0         -1
# 3         VCsim     jacket        17      0        0         1          3
# 4         VCsim       cups        19      0        0         1          7
# ...         ...        ...       ...    ...      ...       ...        ...
# 2768      VCsim  eye_drops         6     99       99         1          8
# 2769      VCsim     jacket        18     99       99         1          3
# 2770      VCsim      advil        15     99       99         1          9
# 2771      VCsim    daisies        10     99       99         1          4
# 2772      VCsim       bass         9     99       99         1          5
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP571      WORD     10.266667          5  0.853172
# 1             2  LTP571      WORD     10.266667          5  0.531313
# 2             3  LTP571      WORD     10.266667          5  0.584174
# 3             4  LTP571      WORD     10.266667          5  0.592274
# 4             5  LTP571      WORD     10.266667          5  0.581184
# ...         ...     ...       ...           ...        ...       ...
# 2768         10  LTP571  REC_WORD      9.666667         15  0.882517
# 2769         11  LTP571  REC_WORD      9.666667         15  0.455670
# 2770         12  LTP571  REC_WORD      9.666667         15  0.774606
# 2771         13  LTP571  REC_WORD      9.666667         15  0.132987
# 2772         15  LTP571  REC_WORD      9.666667         15  0.085394
#
#          pos_y  session
# 0     0.516399        0
# 1     0.583022        0
# 2     0.259052        0
# 3     0.742646        0
# 4     0.074674        0
# ...        ...      ...
# 2768  0.240311        9
# 2769  0.505221        9
# 2770  0.259643        9
# 2771  0.611164        9
# 2772  0.768791        9
#
# [2773 rows x 15 columns]
#      experiment        item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim   head_band        10      0        0         1          2
# 1         VCsim     muffins         9      0       -1         0         -1
# 2         VCsim      helmet         2      0        0         1          4
# 3         VCsim       scale         3      0        0         1         12
# 4         VCsim  blow_dryer        16      0        0         1          1
# ...         ...         ...       ...    ...      ...       ...        ...
# 2657      VCsim      guitar        15     99       99         1          6
# 2658      VCsim       razor        15     99       99         1          1
# 2659      VCsim    chew_toy        13     99       99         1         10
# 2660      VCsim     nailgun         3     99       99         1          7
# 2661      VCsim       basil        10     99       99         1         11
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP572      WORD      8.400000         11  0.368914
# 1             2  LTP572      WORD      8.400000         11  0.749642
# 2             3  LTP572      WORD      8.400000         11  0.452159
# 3             4  LTP572      WORD      8.400000         11  0.799440
# 4             5  LTP572      WORD      8.400000         11  0.491304
# ...         ...     ...       ...           ...        ...       ...
# 2657         10  LTP572  REC_WORD      8.333333          6  0.785823
# 2658         11  LTP572  REC_WORD      8.333333          6  0.592318
# 2659         12  LTP572  REC_WORD      8.333333          6  0.112743
# 2660         13  LTP572  REC_WORD      8.333333          6  0.194883
# 2661         15  LTP572  REC_WORD      8.333333          6  0.745457
#
#          pos_y  session
# 0     0.504727        0
# 1     0.700828        0
# 2     0.097559        0
# 3     0.432364        0
# 4     0.478669        0
# ...        ...      ...
# 2657  0.185801        9
# 2658  0.490013        9
# 2659  0.109972        9
# 2660  0.152004        9
# 2661  0.015573        9
#
# [2662 rows x 15 columns]
#      experiment       item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim      pipes        15      0        0         1          4
# 1         VCsim   bracelet        15      0        0         1          3
# 2         VCsim   computer         5      0       -1         0         -1
# 3         VCsim      light         9      0       -1         0         -1
# 4         VCsim    nailgun         3      0        0         1          7
# ...         ...        ...       ...    ...      ...       ...        ...
# 2488      VCsim  floor_mat        19     99       99         1          2
# 2489      VCsim     hammer         4     99       99         1          5
# 2490      VCsim   ointment         7     99       99         1          6
# 2491      VCsim  head_band        11     99       99         1          4
# 2492      VCsim   vitamins         1     99       99         1         12
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP573      WORD      6.533333         11  0.213967
# 1             2  LTP573      WORD      6.533333         11  0.575411
# 2             3  LTP573      WORD      6.533333         11  0.482168
# 3             4  LTP573      WORD      6.533333         11  0.370171
# 4             5  LTP573      WORD      6.533333         11  0.244926
# ...         ...     ...       ...           ...        ...       ...
# 2488         10  LTP573  REC_WORD      9.133333         11  0.850881
# 2489         11  LTP573  REC_WORD      9.133333         11  0.525879
# 2490         13  LTP573  REC_WORD      9.133333         11  0.795370
# 2491         14  LTP573  REC_WORD      9.133333         11  0.297398
# 2492         15  LTP573  REC_WORD      9.133333         11  0.283813
#
#          pos_y  session
# 0     0.344892        0
# 1     0.390671        0
# 2     0.099587        0
# 3     0.327242        0
# 4     0.396051        0
# ...        ...      ...
# 2488  0.395037        9
# 2489  0.632235        9
# 2490  0.691303        9
# 2491  0.323991        9
# 2492  0.828004        9
#
# [2493 rows x 15 columns]
#      experiment             item  item_val  trial  rectime  recalled  \
# 0         VCsim     baseball_bat        13      0       -1         0
# 1         VCsim      video_games        11      0        0         1
# 2         VCsim  karaoke_machine        12      0        0         1
# 3         VCsim       sweatshirt        10      0        0         1
# 4         VCsim           pliers        16      0        0         1
# ...         ...              ...       ...    ...      ...       ...
# 2898      VCsim    medicine_ball        14     99       99         1
# 2899      VCsim           bagels        10     99       99         1
# 2900      VCsim     orange_juice         1     99       99         1
# 2901      VCsim     tape_measure         8     99       99         1
# 2902      VCsim         dumbells         6     99       99         1
#
#       recallpos  serialpos subject      type  val_list_avg  val_guess  \
# 0            -1          1  LTP574      WORD      9.333333         13
# 1            10          2  LTP574      WORD      9.333333         13
# 2             8          3  LTP574      WORD      9.333333         13
# 3             5          4  LTP574      WORD      9.333333         13
# 4             6          5  LTP574      WORD      9.333333         13
# ...         ...        ...     ...       ...           ...        ...
# 2898          2         10  LTP574  REC_WORD      7.533333         10
# 2899         10         12  LTP574  REC_WORD      7.533333         10
# 2900          4         13  LTP574  REC_WORD      7.533333         10
# 2901          7         14  LTP574  REC_WORD      7.533333         10
# 2902          1         15  LTP574  REC_WORD      7.533333         10
#
#          pos_x     pos_y  session
# 0     0.737823  0.038637        0
# 1     0.305734  0.562956        0
# 2     0.468057  0.587443        0
# 3     0.660616  0.309038        0
# 4     0.664609  0.286184        0
# ...        ...       ...      ...
# 2898  0.696138  0.553986        9
# 2899  0.210635  0.983519        9
# 2900  0.737125  0.787746        9
# 2901  0.520801  0.674145        9
# 2902  0.680871  0.895105        9
#
# [2903 rows x 15 columns]
#      experiment        item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim      guitar        12      0        0         1          7
# 1         VCsim       syrup         5      0        0         1          9
# 2         VCsim    amethyst         9      0        0         1          2
# 3         VCsim   eye_drops         2      0        0         1          4
# 4         VCsim       chain         1      0        0         1          3
# ...         ...         ...       ...    ...      ...       ...        ...
# 2334      VCsim  guinea_pig         7     99       99         1          6
# 2335      VCsim        rope         4     99       99         1          5
# 2336      VCsim     muffins        12     99       99         1          7
# 2337      VCsim       seeds         2     99       99         1          4
# 2338      VCsim   croissant         3     99       99         1          3
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP575      WORD      4.666667         12  0.424130
# 1             2  LTP575      WORD      4.666667         12  0.382547
# 2             3  LTP575      WORD      4.666667         12  0.321280
# 3             4  LTP575      WORD      4.666667         12  0.600239
# 4             5  LTP575      WORD      4.666667         12  0.323718
# ...         ...     ...       ...           ...        ...       ...
# 2334         10  LTP575  REC_WORD      7.333333         10  0.907737
# 2335         11  LTP575  REC_WORD      7.333333         10  0.134818
# 2336         12  LTP575  REC_WORD      7.333333         10  0.610852
# 2337         13  LTP575  REC_WORD      7.333333         10  0.001311
# 2338         14  LTP575  REC_WORD      7.333333         10  0.570989
#
#          pos_y  session
# 0     0.461390        0
# 1     0.220063        0
# 2     0.379929        0
# 3     0.914357        0
# 4     0.920938        0
# ...        ...      ...
# 2334  0.758892        9
# 2335  0.310069        9
# 2336  0.839362        9
# 2337  0.347561        9
# 2338  0.079958        9
#
# [2339 rows x 15 columns]
#      experiment           item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim           gold        15      0        0         1          8
# 1         VCsim          roses        12      0       -1         0         -1
# 2         VCsim      sandpaper        11      0        0         1          4
# 3         VCsim          nails         6      0       -1         0         -1
# 4         VCsim    baking_soda        18      0        0         1          2
# ...         ...            ...       ...    ...      ...       ...        ...
# 2762      VCsim           bass         5     99       99         1          6
# 2763      VCsim       scissors        15     99       99         1          9
# 2764      VCsim  chrysanthemum         9     99       99         1          2
# 2765      VCsim       stickers        11     99       99         1          3
# 2766      VCsim       ointment        13     99       99         1          7
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP576      WORD      9.133333         12  0.827270
# 1             2  LTP576      WORD      9.133333         12  0.595578
# 2             3  LTP576      WORD      9.133333         12  0.520790
# 3             4  LTP576      WORD      9.133333         12  0.043069
# 4             5  LTP576      WORD      9.133333         12  0.596603
# ...         ...     ...       ...           ...        ...       ...
# 2762         10  LTP576  REC_WORD      7.800000         15  0.498438
# 2763         11  LTP576  REC_WORD      7.800000         15  0.951678
# 2764         12  LTP576  REC_WORD      7.800000         15  0.749501
# 2765         13  LTP576  REC_WORD      7.800000         15  0.105070
# 2766         14  LTP576  REC_WORD      7.800000         15  0.927001
#
#          pos_y  session
# 0     0.056027        0
# 1     0.967679        0
# 2     0.396378        0
# 3     0.062299        0
# 4     0.718751        0
# ...        ...      ...
# 2762  0.043534        9
# 2763  0.950569        9
# 2764  0.940577        9
# 2765  0.425396        9
# 2766  0.157300        9
#
# [2767 rows x 15 columns]
#      experiment           item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim     reflectors        12      0       -1         0         -1
# 1         VCsim     blow_dryer         0      0       -1         0         -1
# 2         VCsim  hot_chocolate         5      0       -1         0         -1
# 3         VCsim           menu        17      0        0         1          5
# 4         VCsim  boxing_gloves         4      0        0         1          1
# ...         ...            ...       ...    ...      ...       ...        ...
# 2625      VCsim    baking_soda        14     99       99         1          6
# 2626      VCsim           roll         8     99       99         1          4
# 2627      VCsim           cage        13     99       99         1          2
# 2628      VCsim      harmonica         6     99       99         1          7
# 2629      VCsim      daffodils        10     99       99         1          1
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP577      WORD     10.066667         11  0.772853
# 1             2  LTP577      WORD     10.066667         11  0.675329
# 2             3  LTP577      WORD     10.066667         11  0.713441
# 3             4  LTP577      WORD     10.066667         11  0.007449
# 4             5  LTP577      WORD     10.066667         11  0.255886
# ...         ...     ...       ...           ...        ...       ...
# 2625          9  LTP577  REC_WORD      8.466667         13  0.013398
# 2626         10  LTP577  REC_WORD      8.466667         13  0.871819
# 2627         11  LTP577  REC_WORD      8.466667         13  0.164385
# 2628         13  LTP577  REC_WORD      8.466667         13  0.777883
# 2629         14  LTP577  REC_WORD      8.466667         13  0.687661
#
#          pos_y  session
# 0     0.528977        0
# 1     0.393993        0
# 2     0.561349        0
# 3     0.616686        0
# 4     0.970873        0
# ...        ...      ...
# 2625  0.103967        9
# 2626  0.747612        9
# 2627  0.119257        9
# 2628  0.306052        9
# 2629  0.217077        9
#
# [2630 rows x 15 columns]
#      experiment           item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim           glue        18      0        0         1          8
# 1         VCsim    baking_soda         9      0        0         1         12
# 2         VCsim       computer         0      0        0         1          6
# 3         VCsim    cough_syrup         5      0        0         1          1
# 4         VCsim        sandals        17      0        0         1         13
# ...         ...            ...       ...    ...      ...       ...        ...
# 2751      VCsim      amplifier         7     99       99         1         11
# 2752      VCsim           doll         5     99       99         1          9
# 2753      VCsim      asparagus         8     99       99         1          8
# 2754      VCsim       dumbells         3     99       99         1          4
# 2755      VCsim  medicine_ball         9     99       99         1         10
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP578      WORD      8.933333         11  0.778993
# 1             2  LTP578      WORD      8.933333         11  0.589928
# 2             3  LTP578      WORD      8.933333         11  0.281365
# 3             4  LTP578      WORD      8.933333         11  0.586956
# 4             5  LTP578      WORD      8.933333         11  0.320503
# ...         ...     ...       ...           ...        ...       ...
# 2751         11  LTP578  REC_WORD      5.666667          6  0.100574
# 2752         12  LTP578  REC_WORD      5.666667          6  0.776304
# 2753         13  LTP578  REC_WORD      5.666667          6  0.126172
# 2754         14  LTP578  REC_WORD      5.666667          6  0.661462
# 2755         15  LTP578  REC_WORD      5.666667          6  0.609621
#
#          pos_y  session
# 0     0.083625        0
# 1     0.714567        0
# 2     0.915538        0
# 3     0.952919        0
# 4     0.190145        0
# ...        ...      ...
# 2751  0.850091        9
# 2752  0.622020        9
# 2753  0.953937        9
# 2754  0.854555        9
# 2755  0.329103        9
#
# [2756 rows x 15 columns]
#      experiment            item  item_val  trial  rectime  recalled  \
# 0         VCsim       eye_drops        13      0        0         1
# 1         VCsim       xylophone         0      0       -1         0
# 2         VCsim    curling_iron         5      0       -1         0
# 3         VCsim           cream        19      0       -1         0
# 4         VCsim       ear_plugs         9      0        0         1
# ...         ...             ...       ...    ...      ...       ...
# 2289      VCsim           cream         2     99       99         1
# 2290      VCsim       fish_bowl         8     99       99         1
# 2291      VCsim           floss        13     99       99         1
# 2292      VCsim  stuffed_animal         6     99       99         1
# 2293      VCsim         sandals         9     99       99         1
#
#       recallpos  serialpos subject      type  val_list_avg  val_guess  \
# 0             1          1  LTP579      WORD      9.400000         12
# 1            -1          2  LTP579      WORD      9.400000         12
# 2            -1          3  LTP579      WORD      9.400000         12
# 3            -1          4  LTP579      WORD      9.400000         12
# 4             3          5  LTP579      WORD      9.400000         12
# ...         ...        ...     ...       ...           ...        ...
# 2289          6         11  LTP579  REC_WORD      9.466667         10
# 2290          3         12  LTP579  REC_WORD      9.466667         10
# 2291          2         13  LTP579  REC_WORD      9.466667         10
# 2292          9         14  LTP579  REC_WORD      9.466667         10
# 2293          8         15  LTP579  REC_WORD      9.466667         10
#
#          pos_x     pos_y  session
# 0     0.477929  0.572974        0
# 1     0.930643  0.141900        0
# 2     0.265468  0.272273        0
# 3     0.225615  0.242477        0
# 4     0.320878  0.522444        0
# ...        ...       ...      ...
# 2289  0.011909  0.950476        9
# 2290  0.564301  0.335274        9
# 2291  0.218201  0.706804        9
# 2292  0.941779  0.446194        9
# 2293  0.507098  0.838683        9
#
# [2294 rows x 15 columns]
#      experiment             item  item_val  trial  rectime  recalled  \
# 0         VCsim  karaoke_machine         1      0        0         1
# 1         VCsim        amplifier         0      0       -1         0
# 2         VCsim        kickboard         5      0       -1         0
# 3         VCsim          pastels         1      0        0         1
# 4         VCsim           breaks         0      0        0         1
# ...         ...              ...       ...    ...      ...       ...
# 2533      VCsim      blueberries         6     99       99         1
# 2534      VCsim           shorts         0     99       99         1
# 2535      VCsim   hand_sanitizer        10     99       99         1
# 2536      VCsim             bass        12     99       99         1
# 2537      VCsim         computer         6     99       99         1
#
#       recallpos  serialpos subject      type  val_list_avg  val_guess  \
# 0             4          1  LTP580      WORD      4.666667          1
# 1            -1          2  LTP580      WORD      4.666667          1
# 2            -1          3  LTP580      WORD      4.666667          1
# 3             9          4  LTP580      WORD      4.666667          1
# 4            10          5  LTP580      WORD      4.666667          1
# ...         ...        ...     ...       ...           ...        ...
# 2533          3          5  LTP580  REC_WORD      9.000000         10
# 2534          5         10  LTP580  REC_WORD      9.000000         10
# 2535          6         12  LTP580  REC_WORD      9.000000         10
# 2536          7         13  LTP580  REC_WORD      9.000000         10
# 2537          1         14  LTP580  REC_WORD      9.000000         10
#
#          pos_x     pos_y  session
# 0     0.940441  0.131506        0
# 1     0.089884  0.649013        0
# 2     0.467412  0.680845        0
# 3     0.127247  0.218280        0
# 4     0.932153  0.858089        0
# ...        ...       ...      ...
# 2533  0.932153  0.858089        9
# 2534  0.546802  0.539017        9
# 2535  0.996407  0.414696        9
# 2536  0.008011  0.425650        9
# 2537  0.442667  0.578147        9
#
# [2538 rows x 15 columns]
#      experiment                item  item_val  trial  rectime  recalled  \
# 0         VCsim        orange_juice        14      0        0         1
# 1         VCsim               purse        12      0        0         1
# 2         VCsim    contact_solution         0      0        0         1
# 3         VCsim                suit        13      0        0         1
# 4         VCsim               fruit        15      0        0         1
# ...         ...                 ...       ...    ...      ...       ...
# 2621      VCsim                glue         8     99       99         1
# 2622      VCsim      guitar_strings         8     99       99         1
# 2623      VCsim         cough_syrup        12     99       99         1
# 2624      VCsim  construction_paper         8     99       99         1
# 2625      VCsim              collar         7     99       99         1
#
#       recallpos  serialpos subject      type  val_list_avg  val_guess  \
# 0             1          1  LTP581      WORD      8.666667          6
# 1            12          2  LTP581      WORD      8.666667          6
# 2             8          3  LTP581      WORD      8.666667          6
# 3             9          4  LTP581      WORD      8.666667          6
# 4             6          5  LTP581      WORD      8.666667          6
# ...         ...        ...     ...       ...           ...        ...
# 2621          3          9  LTP581  REC_WORD      7.733333          9
# 2622          1         11  LTP581  REC_WORD      7.733333          9
# 2623          4         12  LTP581  REC_WORD      7.733333          9
# 2624          5         13  LTP581  REC_WORD      7.733333          9
# 2625          6         14  LTP581  REC_WORD      7.733333          9
#
#          pos_x     pos_y  session
# 0     0.951398  0.371661        0
# 1     0.147776  0.699541        0
# 2     0.191304  0.971392        0
# 3     0.262107  0.810198        0
# 4     0.591582  0.091750        0
# ...        ...       ...      ...
# 2621  0.031915  0.089235        9
# 2622  0.065578  0.404367        9
# 2623  0.569026  0.826006        9
# 2624  0.868140  0.898705        9
# 2625  0.163570  0.476242        9
#
# [2626 rows x 15 columns]
#      experiment         item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim     bracelet         8      0       -1         0         -1
# 1         VCsim      emerald        10      0        0         1         11
# 2         VCsim        chain         7      0        0         1          7
# 3         VCsim        bread         1      0        0         1          9
# 4         VCsim         yarn         4      0        0         1          2
# ...         ...          ...       ...    ...      ...       ...        ...
# 2751      VCsim      pastels        15     99       99         1          7
# 2752      VCsim   mozzarella         9     99       99         1          5
# 2753      VCsim       pearls         8     99       99         1          1
# 2754      VCsim       needle         9     99       99         1          2
# 2755      VCsim  blueberries         3     99       99         1          4
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP583      WORD      9.733333          8  0.548951
# 1             2  LTP583      WORD      9.733333          8  0.417150
# 2             3  LTP583      WORD      9.733333          8  0.967781
# 3             4  LTP583      WORD      9.733333          8  0.072580
# 4             5  LTP583      WORD      9.733333          8  0.812365
# ...         ...     ...       ...           ...        ...       ...
# 2751          8  LTP583  REC_WORD      9.000000          8  0.520755
# 2752          9  LTP583  REC_WORD      9.000000          8  0.999687
# 2753         11  LTP583  REC_WORD      9.000000          8  0.671985
# 2754         12  LTP583  REC_WORD      9.000000          8  0.274639
# 2755         13  LTP583  REC_WORD      9.000000          8  0.955198
#
#          pos_y  session
# 0     0.312111        0
# 1     0.125175        0
# 2     0.447131        0
# 3     0.667040        0
# 4     0.355002        0
# ...        ...      ...
# 2751  0.853604        9
# 2752  0.993997        9
# 2753  0.096965        9
# 2754  0.476423        9
# 2755  0.707804        9
#
# [2756 rows x 15 columns]
#      experiment         item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim      canolli        10      0       -1         0         -1
# 1         VCsim     vitamins        15      0        0         1         11
# 2         VCsim     speakers         0      0        0         1          3
# 3         VCsim       garlic        10      0        0         1          1
# 4         VCsim     dumbells         7      0        0         1          6
# ...         ...          ...       ...    ...      ...       ...        ...
# 2964      VCsim  blueberries        10     99       99         1         15
# 2965      VCsim          tie         8     99       99         1          5
# 2966      VCsim       pearls        12     99       99         1         11
# 2967      VCsim    hula_hoop         4     99       99         1          6
# 2968      VCsim       ribbon        10     99       99         1         13
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP584      WORD      9.466667         13  0.636471
# 1             2  LTP584      WORD      9.466667         13  0.943647
# 2             3  LTP584      WORD      9.466667         13  0.374523
# 3             4  LTP584      WORD      9.466667         13  0.460313
# 4             5  LTP584      WORD      9.466667         13  0.483216
# ...         ...     ...       ...           ...        ...       ...
# 2964         11  LTP584  REC_WORD      9.200000          8  0.166231
# 2965         12  LTP584  REC_WORD      9.200000          8  0.944156
# 2966         13  LTP584  REC_WORD      9.200000          8  0.227701
# 2967         14  LTP584  REC_WORD      9.200000          8  0.946974
# 2968         15  LTP584  REC_WORD      9.200000          8  0.018907
#
#          pos_y  session
# 0     0.995477        0
# 1     0.750242        0
# 2     0.886485        0
# 3     0.713671        0
# 4     0.987796        0
# ...        ...      ...
# 2964  0.538799        9
# 2965  0.540648        9
# 2966  0.298657        9
# 2967  0.933152        9
# 2968  0.399671        9
#
# [2969 rows x 15 columns]
#      experiment          item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim        needle        15      0       -1         0         -1
# 1         VCsim          pump         5      0        0         1          8
# 2         VCsim        jacket        15      0        0         1          7
# 3         VCsim         light         8      0        0         1          2
# 4         VCsim          yoyo         9      0       -1         0         -1
# ...         ...           ...       ...    ...      ...       ...        ...
# 2695      VCsim  punching_bag         1     99       99         1          2
# 2696      VCsim      bandages         8     99       99         1          8
# 2697      VCsim      retainer         0     99       99         1          3
# 2698      VCsim      drum_set        13     99       99         1          1
# 2699      VCsim          mice         9     99       99         1          5
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP585      WORD      6.266667          8  0.133895
# 1             2  LTP585      WORD      6.266667          8  0.125024
# 2             3  LTP585      WORD      6.266667          8  0.170053
# 3             4  LTP585      WORD      6.266667          8  0.271020
# 4             5  LTP585      WORD      6.266667          8  0.173990
# ...         ...     ...       ...           ...        ...       ...
# 2695          9  LTP585  REC_WORD      9.733333         12  0.266004
# 2696         10  LTP585  REC_WORD      9.733333         12  0.743347
# 2697         11  LTP585  REC_WORD      9.733333         12  0.378483
# 2698         12  LTP585  REC_WORD      9.733333         12  0.553064
# 2699         13  LTP585  REC_WORD      9.733333         12  0.988617
#
#          pos_y  session
# 0     0.435777        0
# 1     0.405214        0
# 2     0.180985        0
# 3     0.013359        0
# 4     0.863593        0
# ...        ...      ...
# 2695  0.018777        9
# 2696  0.205001        9
# 2697  0.176807        9
# 2698  0.960050        9
# 2699  0.725403        9
#
# [2700 rows x 15 columns]
#      experiment            item  item_val  trial  rectime  recalled  \
# 0         VCsim            rope         7      0        0         1
# 1         VCsim  guitar_strings         3      0        0         1
# 2         VCsim        speakers         5      0       -1         0
# 3         VCsim         spinach         7      0        0         1
# 4         VCsim       amplifier         8      0        0         1
# ...         ...             ...       ...    ...      ...       ...
# 2881      VCsim            gold         8     99       99         1
# 2882      VCsim           chain        10     99       99         1
# 2883      VCsim          hammer        12     99       99         1
# 2884      VCsim       amplifier         8     99       99         1
# 2885      VCsim          lilies        10     99       99         1
#
#       recallpos  serialpos subject      type  val_list_avg  val_guess  \
# 0             3          1  LTP586      WORD      6.666667          9
# 1             9          2  LTP586      WORD      6.666667          9
# 2            -1          3  LTP586      WORD      6.666667          9
# 3             8          4  LTP586      WORD      6.666667          9
# 4            14          5  LTP586      WORD      6.666667          9
# ...         ...        ...     ...       ...           ...        ...
# 2881         10          9  LTP586  REC_WORD      9.466667          7
# 2882          9         10  LTP586  REC_WORD      9.466667          7
# 2883          8         13  LTP586  REC_WORD      9.466667          7
# 2884         12         14  LTP586  REC_WORD      9.466667          7
# 2885          2         15  LTP586  REC_WORD      9.466667          7
#
#          pos_x     pos_y  session
# 0     0.192942  0.607940        0
# 1     0.615081  0.380664        0
# 2     0.088929  0.750627        0
# 3     0.531661  0.193258        0
# 4     0.395665  0.139350        0
# ...        ...       ...      ...
# 2881  0.628155  0.620140        9
# 2882  0.625643  0.176213        9
# 2883  0.733478  0.199718        9
# 2884  0.966994  0.341224        9
# 2885  0.684573  0.753053        9
#
# [2886 rows x 15 columns]
#      experiment         item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim        drill         5      0       -1         0         -1
# 1         VCsim       turtle         3      0        0         1          1
# 2         VCsim    back_pack         5      0        0         1          2
# 3         VCsim  screwdriver         1      0        0         1          9
# 4         VCsim       q-tips         5      0       -1         0         -1
# ...         ...          ...       ...    ...      ...       ...        ...
# 2612      VCsim       thread        12     99       99         1         14
# 2613      VCsim      diamond         2     99       99         1          9
# 2614      VCsim        scarf         2     99       99         1          1
# 2615      VCsim    saxophone         1     99       99         1          4
# 2616      VCsim    chocolate         9     99       99         1          7
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP587      WORD      6.200000          4  0.533727
# 1             2  LTP587      WORD      6.200000          4  0.177327
# 2             3  LTP587      WORD      6.200000          4  0.761519
# 3             4  LTP587      WORD      6.200000          4  0.140379
# 4             5  LTP587      WORD      6.200000          4  0.480877
# ...         ...     ...       ...           ...        ...       ...
# 2612         10  LTP587  REC_WORD      4.466667          0  0.115724
# 2613         11  LTP587  REC_WORD      4.466667          0  0.587411
# 2614         12  LTP587  REC_WORD      4.466667          0  0.523854
# 2615         13  LTP587  REC_WORD      4.466667          0  0.593208
# 2616         15  LTP587  REC_WORD      4.466667          0  0.582435
#
#          pos_y  session
# 0     0.208320        0
# 1     0.452842        0
# 2     0.841733        0
# 3     0.102997        0
# 4     0.959905        0
# ...        ...      ...
# 2612  0.226233        9
# 2613  0.496189        9
# 2614  0.086609        9
# 2615  0.622913        9
# 2616  0.120366        9
#
# [2617 rows x 15 columns]
#      experiment       item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim     screws         9      0        0         1         12
# 1         VCsim    spinach         4      0        0         1         13
# ...
# 2587          5         12  LTP598  REC_WORD     10.533333         10
# 2588          4         13  LTP598  REC_WORD     10.533333         10
# 2589          1         14  LTP598  REC_WORD     10.533333         10
#
#          pos_x     pos_y  session
# 0     0.214408  0.595519        0
# 1     0.041598  0.309130        0
# 2     0.002853  0.052844        0
# 3     0.412741  0.293927        0
# 4     0.378749  0.726766        0
# ...        ...       ...      ...
# 2585  0.389262  0.860642        9
# 2586  0.213883  0.587954        9
# 2587  0.919736  0.716402        9
# 2588  0.631480  0.636647        9
# 2589  0.124085  0.312073        9
#
# [2590 rows x 15 columns]
#      experiment        item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim      straws        12      0        0         1          2
# 1         VCsim      cereal        13      0       -1         0         -1
# 2         VCsim     peonies         8      0       -1         0         -1
# 3         VCsim  toothpaste         9      0       -1         0         -1
# 4         VCsim        suit         3      0       -1         0         -1
# ...         ...         ...       ...    ...      ...       ...        ...
# 2144      VCsim       nails         5     99       99         1          1
# 2145      VCsim     oregano         4     99       99         1          2
# 2146      VCsim   fish_bowl         0     99       99         1          4
# 2147      VCsim       level         1     99       99         1          5
# 2148      VCsim    computer         9     99       99         1          3
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP599      WORD      9.266667          7  0.532185
# 1             2  LTP599      WORD      9.266667          7  0.201652
# 2             3  LTP599      WORD      9.266667          7  0.275902
# 3             4  LTP599      WORD      9.266667          7  0.439850
# 4             5  LTP599      WORD      9.266667          7  0.829153
# ...         ...     ...       ...           ...        ...       ...
# 2144          3  LTP599  REC_WORD      4.333333          4  0.275902
# 2145          8  LTP599  REC_WORD      4.333333          4  0.406825
# 2146          9  LTP599  REC_WORD      4.333333          4  0.083902
# 2147         13  LTP599  REC_WORD      4.333333          4  0.280243
# 2148         14  LTP599  REC_WORD      4.333333          4  0.484673
#
#          pos_y  session
# 0     0.615246        0
# 1     0.898247        0
# 2     0.794633        0
# 3     0.173118        0
# 4     0.100739        0
# ...        ...      ...
# 2144  0.794633        9
# 2145  0.102841        9
# 2146  0.030997        9
# 2147  0.858570        9
# 2148  0.136393        9
#
# [2149 rows x 15 columns]
#      experiment             item  item_val  trial  rectime  recalled  \
# 0         VCsim  chocolate_chips         4      0        0         1
# 1         VCsim             bell        16      0        0         1
# 2         VCsim            paint         2      0        0         1
# 3         VCsim         bracelet        14      0        0         1
# 4         VCsim            level         8      0        0         1
# ...         ...              ...       ...    ...      ...       ...
# 2838      VCsim          daisies         7     99       99         1
# 2839      VCsim      video_games        15     99       99         1
# 2840      VCsim    boxing_gloves         0     99       99         1
# 2841      VCsim            chain        14     99       99         1
# 2842      VCsim        anchovies         5     99       99         1
#
#       recallpos  serialpos subject      type  val_list_avg  val_guess  \
# 0            10          1  LTP600      WORD      7.666667         15
# 1             7          2  LTP600      WORD      7.666667         15
# 2            12          3  LTP600      WORD      7.666667         15
# 3            15          4  LTP600      WORD      7.666667         15
# 4            14          5  LTP600      WORD      7.666667         15
# ...         ...        ...     ...       ...           ...        ...
# 2838         12         11  LTP600  REC_WORD      9.333333         10
# 2839          7         12  LTP600  REC_WORD      9.333333         10
# 2840          3         13  LTP600  REC_WORD      9.333333         10
# 2841          1         14  LTP600  REC_WORD      9.333333         10
# 2842         15         15  LTP600  REC_WORD      9.333333         10
#
#          pos_x     pos_y  session
# 0     0.785371  0.670504        0
# 1     0.621665  0.077173        0
# 2     0.255088  0.944662        0
# 3     0.699119  0.906837        0
# 4     0.900430  0.469992        0
# ...        ...       ...      ...
# 2838  0.246853  0.425792        9
# 2839  0.810528  0.586245        9
# 2840  0.239810  0.173442        9
# 2841  0.704147  0.311084        9
# 2842  0.478416  0.951444        9
#
# [2843 rows x 15 columns]
#      experiment             item  item_val  trial  rectime  recalled  \
# 0         VCsim         platinum         8      0       -1         0
# 1         VCsim             soil         5      0       -1         0
# 2         VCsim  karaoke_machine        11      0        0         1
# 3         VCsim           lilies        15      0        0         1
# 4         VCsim         ointment        15      0        0         1
# ...         ...              ...       ...    ...      ...       ...
# 2779      VCsim    bottled_water         0     99       99         1
# 2780      VCsim           jacket         9     99       99         1
# 2781      VCsim           wrench        12     99       99         1
# 2782      VCsim       reflectors        17     99       99         1
# 2783      VCsim          peonies        11     99       99         1
#
#       recallpos  serialpos subject      type  val_list_avg  val_guess  \
# 0            -1          1  LTP601      WORD      8.866667         11
# 1            -1          2  LTP601      WORD      8.866667         11
# 2             7          3  LTP601      WORD      8.866667         11
# 3             8          4  LTP601      WORD      8.866667         11
# 4             4          5  LTP601      WORD      8.866667         11
# ...         ...        ...     ...       ...           ...        ...
# 2779          3         10  LTP601  REC_WORD      9.933333         15
# 2780          4         11  LTP601  REC_WORD      9.933333         15
# 2781          9         12  LTP601  REC_WORD      9.933333         15
# 2782         10         13  LTP601  REC_WORD      9.933333         15
# 2783          1         15  LTP601  REC_WORD      9.933333         15
#
#          pos_x     pos_y  session
# 0     0.094927  0.996035        0
# 1     0.070281  0.311670        0
# 2     0.680983  0.392738        0
# 3     0.106769  0.906184        0
# 4     0.492997  0.319168        0
# ...        ...       ...      ...
# 2779  0.289985  0.087926        9
# 2780  0.528862  0.382051        9
# 2781  0.736041  0.592033        9
# 2782  0.201712  0.239282        9
# 2783  0.899058  0.789090        9
#
# [2784 rows x 15 columns]
#      experiment            item  item_val  trial  rectime  recalled  \
# 0         VCsim        recorder        10      0        0         1
# 1         VCsim       back_pack         1      0        0         1
# 2         VCsim         daisies         2      0        0         1
# 3         VCsim          screws        12      0        0         1
# 4         VCsim          mirror         7      0        0         1
# ...         ...             ...       ...    ...      ...       ...
# 2756      VCsim           scale         3     99       99         1
# 2757      VCsim          straws        12     99       99         1
# 2758      VCsim         diamond        13     99       99         1
# 2759      VCsim  protein_shakes         5     99       99         1
# 2760      VCsim       daffodils         1     99       99         1
#
#       recallpos  serialpos subject      type  val_list_avg  val_guess  \
# 0             1          1  LTP602      WORD      8.733333          8
# 1            12          2  LTP602      WORD      8.733333          8
# 2             5          3  LTP602      WORD      8.733333          8
# 3             3          4  LTP602      WORD      8.733333          8
# 4            13          5  LTP602      WORD      8.733333          8
# ...         ...        ...     ...       ...           ...        ...
# 2756          3         10  LTP602  REC_WORD      5.933333          9
# 2757         13         11  LTP602  REC_WORD      5.933333          9
# 2758         10         12  LTP602  REC_WORD      5.933333          9
# 2759         14         13  LTP602  REC_WORD      5.933333          9
# 2760          9         14  LTP602  REC_WORD      5.933333          9
#
#          pos_x     pos_y  session
# 0     0.990167  0.441094        0
# 1     0.600618  0.765219        0
# 2     0.934723  0.292546        0
# 3     0.042168  0.814013        0
# 4     0.676022  0.697451        0
# ...        ...       ...      ...
# 2756  0.967740  0.908738        9
# 2757  0.882528  0.886130        9
# 2758  0.115570  0.230675        9
# 2759  0.893593  0.474979        9
# 2760  0.359346  0.555127        9
#
# [2761 rows x 15 columns]
#      experiment              item  item_val  trial  rectime  recalled  \
# 0         VCsim              mice        15      0        0         1
# 1         VCsim             cream        10      0        0         1
# 2         VCsim          ointment         4      0       -1         0
# 3         VCsim            pliers         3      0       -1         0
# 4         VCsim         jump_rope         8      0        0         1
# ...         ...               ...       ...    ...      ...       ...
# 2387      VCsim  allergy_medicine        18     98       98         1
# 2388      VCsim            decals         0     99       99         1
# 2389      VCsim           cookies         9     99       99         1
# 2390      VCsim          fluoride         3     99       99         1
# 2391      VCsim         hula_hoop         3     99       99         1
#
#       recallpos  serialpos subject      type  val_list_avg  val_guess  \
# 0             6          1  LTP603      WORD      7.133333          8
# 1             7          2  LTP603      WORD      7.133333          8
# 2            -1          3  LTP603      WORD      7.133333          8
# 3            -1          4  LTP603      WORD      7.133333          8
# 4             2          5  LTP603      WORD      7.133333          8
# ...         ...        ...     ...       ...           ...        ...
# 2387          8         14  LTP603  REC_WORD     10.066667          9
# 2388          2          2  LTP603  REC_WORD      5.466667          9
# 2389          3          7  LTP603  REC_WORD      5.466667          9
# 2390          1         10  LTP603  REC_WORD      5.466667          9
# 2391          4         14  LTP603  REC_WORD      5.466667          9
#
#          pos_x     pos_y  session
# 0     0.274131  0.028244        0
# 1     0.420470  0.431897        0
# 2     0.640111  0.287406        0
# 3     0.534993  0.092573        0
# 4     0.960279  0.873139        0
# ...        ...       ...      ...
# 2387  0.946303  0.827636        9
# 2388  0.420470  0.431897        9
# 2389  0.176640  0.072256        9
# 2390  0.450869  0.686060        9
# 2391  0.946303  0.827636        9
#
# [2392 rows x 15 columns]
#      experiment           item  item_val  trial  rectime  recalled  recallpos  \
# 0         VCsim   curling_iron        11      0        0         1          9
# 1         VCsim          purse         4      0        0         1          5
# 2         VCsim        markers         3      0       -1         0         -1
# 3         VCsim      hula_hoop         9      0       -1         0         -1
# 4         VCsim           glue         2      0       -1         0         -1
# ...         ...            ...       ...    ...      ...       ...        ...
# 2331      VCsim  tracing_paper        11     99       99         1          3
# 2332      VCsim       dumbells         0     99       99         1          6
# 2333      VCsim        spackle         6     99       99         1          2
# 2334      VCsim          razor         8     99       99         1          7
# 2335      VCsim     guinea_pig         6     99       99         1          1
#
#       serialpos subject      type  val_list_avg  val_guess     pos_x  \
# 0             1  LTP604      WORD      5.933333          5  0.781106
# 1             2  LTP604      WORD      5.933333          5  0.953343
# 2             3  LTP604      WORD      5.933333          5  0.633819
# 3             4  LTP604      WORD      5.933333          5  0.606854
# 4             5  LTP604      WORD      5.933333          5  0.284858
# ...         ...     ...       ...           ...        ...       ...
# 2331          7  LTP604  REC_WORD      6.533333         10  0.474902
# 2332          8  LTP604  REC_WORD      6.533333         10  0.960127
# 2333          9  LTP604  REC_WORD      6.533333         10  0.196341
# 2334         10  LTP604  REC_WORD      6.533333         10  0.455041
# 2335         15  LTP604  REC_WORD      6.533333         10  0.584676
#
#          pos_y  session
# 0     0.846670        0
# 1     0.509797        0
# 2     0.868576        0
# 3     0.298144        0
# 4     0.831831        0
# ...        ...      ...
# 2331  0.244718        9
# 2332  0.387494        9
# 2333  0.011538        9
# 2334  0.068532        9
# 2335  0.976826        9
#
# [2336 rows x 15 columns]
#      experiment             item  item_val  trial  rectime  recalled  \
# 0         VCsim       sweatshirt        17      0       -1         0
# 1         VCsim      sweet-n-low        10      0        0         1
# 2         VCsim           breaks        19      0        0         1
# 3         VCsim           pearls        14      0       -1         0
# 4         VCsim    half-and-half        12      0       -1         0
# ...         ...              ...       ...    ...      ...       ...
# 2185      VCsim        kickboard        15     99       99         1
# 2186      VCsim           cereal         9     99       99         1
# 2187      VCsim          cookies         2     99       99         1
# 2188      VCsim  chocolate_chips         1     99       99         1
# 2189      VCsim              cat        11     99       99         1
#
#       recallpos  serialpos subject      type  val_list_avg  val_guess  \
# 0            -1          1  LTP605      WORD     11.066667         15
# 1             5          2  LTP605      WORD     11.066667         15
# 2             8          3  LTP605      WORD     11.066667         15
# 3            -1          4  LTP605      WORD     11.066667         15
# 4            -1          5  LTP605      WORD     11.066667         15
# ...         ...        ...     ...       ...           ...        ...
# 2185          9          6  LTP605  REC_WORD      8.466667          8
# 2186          7          7  LTP605  REC_WORD      8.466667          8
# 2187          2          9  LTP605  REC_WORD      8.466667          8
# 2188         10         12  LTP605  REC_WORD      8.466667          8
# 2189          3         14  LTP605  REC_WORD      8.466667          8
#
#          pos_x     pos_y  session
# 0     0.670686  0.502021        0
# 1     0.577300  0.380096        0
# 2     0.386321  0.692856        0
# 3     0.430386  0.031936        0
# 4     0.635892  0.847995        0
# ...        ...       ...      ...
# 2185  0.854385  0.603676        9
# 2186  0.664813  0.545365        9
# 2187  0.971334  0.199496        9
# 2188  0.009683  0.034791        9
# 2189  0.121398  0.999717        9
#
# [2190 rows x 15 columns]

# %%
sim_crps = {}

for sub, df_sim in sim_dfs.items():
    sim_crps[sub] = compute_lag_crp_single_subject_array(df_sim, list_len)
# Out:
# session 1, trial 12 doesn't have enough events
# session 2, trial 27 doesn't have enough events
# session 6, trial 64 doesn't have enough events
# session 2, trial 26 doesn't have enough events

# %%
fig, axes = plt.subplots(nrows=5, ncols=8, figsize=(24, 12.5), sharex=True, sharey=True)
axes = axes.flatten()

lags = np.arange(-(list_len-1), list_len)
mask = lags != 0
lags = lags[mask]

for ax, sub in zip(axes, sub_parameters.keys()):
    cr1_sub_crp = sub_parameters[sub]['lag_crp'][mask]
    sim_sub_crp = sim_crps.get(sub)
    # sim_sub_crp[len(sim_sub_crp) // 2] = np.nan
    # print(sim_sub_crp)
    if sim_sub_crp is not None:
        sim_sub_crp = sim_sub_crp[mask]
        ax.plot(lags, cr1_sub_crp, label="CourierReinstate1")
        ax.plot(lags, sim_sub_crp, linestyle="--", label="Simulated")
    ax.set_title(str(sub), fontsize=10)
    ax.tick_params(labelsize=8)

fig.suptitle("CR1 vs Simulated Lag CRPs", fontsize=16)
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper right")
plt.tight_layout()
plt.show()

# %%
cr1_all_crp = None
sim_all_crp = None
cr1_stack = np.vstack([sub_parameters[sub]['lag_crp'] for sub in sub_parameters])
sim_stack = np.vstack([sim_crps.get(sub) for sub in sub_parameters if sub in sim_crps])
cr1_all_crp = cr1_stack.mean(axis=0)
sim_all_crp = sim_stack.mean(axis=0)

lags = np.arange(-(list_len-1), list_len)
# Create a mask for valid values (nonzero lag and non-NaN CRPs)
mask = (lags != 0) & (~np.isnan(cr1_all_crp)) & (~np.isnan(sim_all_crp))

plt.figure(figsize=(8, 6))
plt.plot(lags[mask], cr1_all_crp[mask], label="CourierReinstate1")
plt.plot(lags[mask], sim_all_crp[mask], linestyle="--", label="Simulated")
plt.xlabel('Lag')
plt.ylabel('Conditional Response Probability')
plt.title('Across Subjects Average Lag CRP')
plt.legend()
plt.tight_layout()
plt.show()

# %%
errors = {}
lags = np.arange(-(list_len-1), list_len)
mask = lags != 0
lags = lags[mask]
        
for sub in sub_parameters.keys():
    if sub in sim_crps:
        cr1_sub_crp = sub_parameters[sub]['lag_crp'][mask]
        sim_sub_crp = sim_crps.get(sub)
        if sim_sub_crp is not None:
            sim_sub_crp = sim_sub_crp[mask]
        errors[sub] = np.sqrt(((cr1_sub_crp - sim_sub_crp) ** 2).mean())
    
errors
# Out:
# {'LTP564': 0.0780507600454574,
#  'LTP565': 0.12112410390691634,
#  'LTP566': 0.07883470398184889,
#  'LTP567': 0.05683152862772664,
#  'LTP568': 0.05707139920205263,
#  'LTP569': 0.05584815933319613,
#  'LTP571': 0.053912204580677164,
#  'LTP572': 0.08768875079252345,
#  'LTP573': 0.07380366261514588,
#  'LTP574': 0.09554377622477649,
#  'LTP575': 0.05142771626111297,
#  'LTP576': 0.09655315020936411,
#  'LTP577': 0.07198135751387463,
#  'LTP578': 0.08358483603150216,
#  'LTP579': nan,
#  'LTP580': 0.05676515721357764,
#  'LTP581': 0.04262010881116513,
#  'LTP583': 0.0697434700031568,
#  'LTP584': nan,
#  'LTP585': 0.07046547188988161,
#  'LTP586': 0.05831156952397844,
#  'LTP587': 0.09156741328515886,
#  'LTP588': 0.05347396577171388,
#  'LTP589': 0.10083607172761684,
#  'LTP590': 0.06838991645489904,
#  'LTP591': 0.08160399159376945,
#  'LTP592': 0.08630492854265397,
#  'LTP593': 0.06493912300718746,
#  'LTP594': 0.0923006567512362,
#  'LTP595': 0.07475918789955112,
#  'LTP596': 0.050010739100170315,
#  'LTP597': 0.03945711176322231,
#  'LTP598': 0.059669624952694476,
#  'LTP599': 0.05258770994178918,
#  'LTP600': nan,
#  'LTP601': 0.07684923321555426,
#  'LTP602': 0.07351949783593249,
#  'LTP603': 0.11225554379287739,
#  'LTP604': 0.08546434279857253,
#  'LTP605': 0.047685374298312995}

# %%
avg_error = np.nanmean(list(errors.values()))
avg_error
# Out:
# 0.07221179241894181
