# %%
import pandas as pd
import numpy as np
import random
from SimulatedSubjectData import *
import matplotlib.pyplot as plt
import pickle

# %%
def save_data(data, filename):
    """
    Save a dictionary where keys are ints or tuples, and values are lists of time series arrays.

    Parameters
    ----------
    data_dict : dict
        Keys: int or tuple (e.g., 1, (2,4))
        Values: list of lists or numpy arrays (time series data)
    filename : str
        Path to save file (should end in .pkl)
    """
    with open(filename, 'wb') as f:
        pickle.dump(data, f, protocol=pickle.HIGHEST_PROTOCOL)
    print(f"Dictionary saved to {filename}")

def load_data(filename):
    """
    Load a dictionary saved with save_timeseries_dict().
    """
    with open(filename, 'rb') as f:
        return pickle.load(f)

# %%
with open("words.pkl", "rb") as f:
    wordpool = pickle.load(f)

# %%
item_list_rand = ItemList(15, condition="Random", wordpool=wordpool,complex_temp=True)
item_list_temp = ItemList(15, condition="Temporal",complex_temp=True)

# Plot the values
plt.plot(item_list_rand.vals, label="Random", marker='o')
plt.plot(item_list_temp.vals, label="Temporal", marker='o')

# Shade primacy (first 0–1 positions) in green
plt.axvspan(0 , 2 - 0.5, color='green', alpha=0.2)  # adjust -0.5 for marker centering

plt.axvspan(2 - 0.5, 7 - 0.5, color='magenta', alpha=0.2)  # adjust -0.5 for marker centering

plt.axvspan(7 - 0.5, 12 - 0.5, color='yellow', alpha=0.2)  # adjust -0.5 for marker centering

# Shade recency (last 3 positions) in red
n = len(item_list_temp.vals)
plt.axvspan(n - 3 - 0.5, n, color='red', alpha=0.2)

# Labels and legend
plt.xlabel("Serial Position")
plt.ylabel("Value")
plt.title("Item Values by Condition")
plt.legend()
plt.show()

# %%
# num_lists = 500
# list_len = 15

# # Range is 1-20
# simple_params = {
#     "val_range": (1, 20),
#     "recency_buf": 3,
#     "primacy_buf": 2, 
#     "num_in_group_chosen": 4,
#     "high_first": True, 
# }
# rand_lists = np.array([ItemList(list_len, condition="Random").vals for _ in range(num_lists)])
# temp_first_high_lists = np.array([ItemList(list_len, condition="Temporal").vals for _ in range(num_lists)])
# simple_params = {
#     "val_range": (1, 20),
#     "recency_buf": 3,
#     "primacy_buf": 2, 
#     "num_in_group_chosen": 4,
#     "high_first": False, 
# }
# temp_first_low_lists = np.array([ItemList(list_len, condition="Temporal",simple_params=simple_params).vals for _ in range(num_lists)])


# # Compute mean across serial position
# rand_mean = rand_lists.mean(axis=0)
# temp_first_high_mean = temp_first_high_lists.mean(axis=0)
# temp_first_low_mean = temp_first_low_lists.mean(axis=0)

# # Compute mean of each list
# rand_list_means = rand_lists.mean(axis=1)
# temp_high_list_means = temp_first_high_lists.mean(axis=1)
# temp_low_list_means = temp_first_low_lists.mean(axis=1)

# # Compute average and standard deviation across list means
# results = {
#     "Random": (rand_list_means.mean(), np.std(rand_list_means)),
#     "Temporal High First": (temp_high_list_means.mean(), np.std(temp_high_list_means)),
#     "Temporal Low First": (temp_low_list_means.mean(), np.std(temp_low_list_means))
# }

# # Print results
# for condition, (mean_val, std_val) in results.items():
#     print(f"{condition}: Mean of list means = {mean_val:.3f}, Std of list means = {std_val:.3f}")


# # Plot mean values
# plt.figure(figsize=(10, 6))
# plt.plot(rand_mean, label="Random", marker='o')
# plt.plot(temp_first_high_mean, label="Temporal High First", marker='o')

# plt.plot(temp_first_low_mean, label="Temporal Low First", marker='o')

# # Shade primacy (first 0–1 positions) in green
# plt.axvspan(0 , 2 - 0.5, color='green', alpha=0.2)  # adjust -0.5 for marker centering

# plt.axvspan(2 - 0.5, 7 - 0.5, color='magenta', alpha=0.2)  # adjust -0.5 for marker centering

# plt.axvspan(7 - 0.5, 12 - 0.5, color='yellow', alpha=0.2)  # adjust -0.5 for marker centering

# # Shade recency (last 3 positions) in red
# n = len(item_list_temp.vals)
# plt.axvspan(n - 3 - 0.5, n, color='red', alpha=0.2)

# # Labels and title
# plt.xlabel("Serial Position")
# plt.ylabel("Average Value")
# plt.title(f"Averaged Item Values Across {num_lists} Lists per Condition")
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# conditions = {
#     "Random": rand_list_means,
#     "Temporal High First": temp_high_list_means,
#     "Temporal Low First": temp_low_list_means
# }

# num_conditions = len(conditions)
# fig, axes = plt.subplots(num_conditions, 1, figsize=(12, 4 * num_conditions), sharex=True)

# if num_conditions == 1:
#     axes = [axes]  # ensure axes is iterable

# for ax, (cond_name, list_means) in zip(axes, conditions.items()):
#     mean_val = np.mean(list_means)
#     std_val = np.std(list_means)
    
#     # Plot list means
#     ax.plot(list_means, label=f"{cond_name} (Mean={mean_val:.2f}, Std={std_val:.2f})", color='blue')
    
#     ax.set_ylabel("Mean Value")
#     ax.set_title(cond_name)
#     ax.legend()

# axes[-1].set_xlabel("List Index")
# plt.tight_layout()
# plt.show()

# %%
# SIMPLE averaged across item values
num_lists = 1000
list_len = 15

# Range is 1-20
simple_params = {
    "val_range": (1, 50),
    "recency_buf": 3,
    "primacy_buf": 2, 
    "num_in_group_chosen": 4,
    "high_first": True,  # default; will be overwritten during list generation
    "target_var": [5, 20],
    "target_mean": [10,40]
}
rand_lists = np.array([ItemList(list_len, condition="Random", simple_params=simple_params).vals for _ in range(num_lists)])
temp_first_high_lists = np.array([ItemList(list_len, condition="Temporal", simple_params=simple_params).vals for _ in range(num_lists)])
simple_params = {
    "val_range": (1, 50),
    "recency_buf": 3,
    "primacy_buf": 2, 
    "num_in_group_chosen": 4,
    "high_first": False,  # default; will be overwritten during list generation
    "target_var": [5,20],
    "target_mean": [10,40]
}
temp_first_low_lists = np.array([ItemList(list_len, condition="Temporal",simple_params=simple_params).vals for _ in range(num_lists)])


# Compute mean across serial position
rand_mean = rand_lists.mean(axis=0)
temp_first_high_mean = temp_first_high_lists.mean(axis=0)
temp_first_low_mean = temp_first_low_lists.mean(axis=0)

# Compute mean of each list
rand_list_means = rand_lists.mean(axis=1)
temp_high_list_means = temp_first_high_lists.mean(axis=1)
temp_low_list_means = temp_first_low_lists.mean(axis=1)

# Compute average and standard deviation across list means
results = {
    "Random": (rand_list_means.mean(), np.std(rand_list_means)),
    "Temporal High First": (temp_high_list_means.mean(), np.std(temp_high_list_means)),
    "Temporal Low First": (temp_low_list_means.mean(), np.std(temp_low_list_means))
}

# Print results
for condition, (mean_val, std_val) in results.items():
    print(f"{condition}: Mean of list means = {mean_val:.3f}, Std of list means = {std_val:.3f}")


# Plot mean values
plt.figure(figsize=(10, 6))
plt.plot(rand_mean, label="Random", marker='o')
plt.plot(temp_first_high_mean, label="Temporal High First", marker='o')

plt.plot(temp_first_low_mean, label="Temporal Low First", marker='o')

# Shade primacy (first 0–1 positions) in green
plt.axvspan(0 , 2 - 0.5, color='green', alpha=0.2)  # adjust -0.5 for marker centering

plt.axvspan(2 - 0.5, 7 - 0.5, color='magenta', alpha=0.2)  # adjust -0.5 for marker centering

plt.axvspan(7 - 0.5, 12 - 0.5, color='yellow', alpha=0.2)  # adjust -0.5 for marker centering

# Shade recency (last 3 positions) in red
n = len(item_list_temp.vals)
plt.axvspan(n - 3 - 0.5, n, color='red', alpha=0.2)

# Labels and title
plt.xlabel("Serial Position")
plt.ylabel("Average Value")
plt.title(f"Averaged Item Values Across {num_lists} Lists per Condition")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Random: Mean of list means = 24.622, Std of list means = 8.564
# Temporal High First: Mean of list means = 24.576, Std of list means = 8.477
# Temporal Low First: Mean of list means = 24.679, Std of list means = 8.848

# %%
# COMPLEX averaged across item values
num_lists = 1000
list_len = 15

rand_complex_lists = np.array([ItemList(list_len, condition="Random", complex_temp=True).vals for _ in range(num_lists)])
temp_complex_lists = np.array([ItemList(list_len, condition="Temporal", complex_temp=True).vals for _ in range(num_lists)])

# Compute mean across serial position
rand_complex_mean = rand_complex_lists.mean(axis=0)
temp_complex_mean = temp_complex_lists.mean(axis=0)

# Compute mean of each list
rand_complex_list_means = rand_complex_lists.mean(axis=1)
temp_complex_list_means = temp_complex_lists.mean(axis=1)

# Compute average and standard deviation across list means
results = {
    "Random Old": (rand_complex_list_means.mean(), np.std(rand_complex_list_means)),
    "Temporal Old": (temp_complex_list_means.mean(), np.std(temp_complex_list_means)),
    "Random New": (rand_list_means.mean(), np.std(rand_list_means)),
    "Temporal New High First": (temp_high_list_means.mean(), np.std(temp_high_list_means)),
    "Temporal New Low First": (temp_low_list_means.mean(), np.std(temp_low_list_means))
}

# Print results
for condition, (mean_val, std_val) in results.items():
    print(f"{condition}: Mean of list means = {mean_val:.3f}, Std of list means = {std_val:.3f}")


# Plot mean values
plt.figure(figsize=(10, 6))
plt.plot(rand_complex_mean, label="Random Old", marker='o')
plt.plot(temp_complex_mean, label="Temporal Old", marker='o')
plt.plot(rand_mean, label="Random New", marker='o')
plt.plot(temp_first_high_mean, label="Temporal New High First", marker='o')
plt.plot(temp_first_low_mean, label="Temporal New Low First", marker='o')
# Shade primacy (first 0–1 positions) in green
plt.axvspan(0 , 2 - 0.5, color='green', alpha=0.2)  # adjust -0.5 for marker centering

plt.axvspan(2 - 0.5, 7 - 0.5, color='magenta', alpha=0.2)  # adjust -0.5 for marker centering

plt.axvspan(7 - 0.5, 12 - 0.5, color='yellow', alpha=0.2)  # adjust -0.5 for marker centering

# Shade recency (last 3 positions) in red
n = len(item_list_temp.vals)
plt.axvspan(n - 3 - 0.5, n, color='red', alpha=0.2)

# Labels and title
plt.xlabel("Serial Position")
plt.ylabel("Average Value")
plt.title(f"Averaged Item Values Across {num_lists} Lists per Condition")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Random Old: Mean of list means = 24.667, Std of list means = 8.719
# Temporal Old: Mean of list means = 24.962, Std of list means = 8.237
# Random New: Mean of list means = 24.622, Std of list means = 8.564
# Temporal New High First: Mean of list means = 24.576, Std of list means = 8.477
# Temporal New Low First: Mean of list means = 24.679, Std of list means = 8.848

# %%
# plot all complex ontop of each other
import numpy as np
import matplotlib.pyplot as plt
num_lists = 100
list_len = 15

rand_complex_lists = np.array([ItemList(list_len, condition="Random", complex_temp=True).vals for _ in range(num_lists)])
temp_complex_lists = np.array([ItemList(list_len, condition="Temporal", complex_temp=True).vals for _ in range(num_lists)])

# Assuming these already exist from your code:
# rand_complex_lists: shape (num_lists, list_len)
# temp_complex_lists: shape (num_lists, list_len)
# num_lists, list_len defined

def plot_overlay(lists, title, shade_regions=True, alpha=0.05, lw=1.0, show_mean=True):
    """
    lists: np.ndarray of shape (num_lists, list_len)
    """
    plt.figure(figsize=(10, 6))

    x = np.arange(lists.shape[1])

    # plot every list
    for i in range(lists.shape[0]):
        plt.plot(x, lists[i], alpha=alpha, linewidth=lw)

    # overlay mean
    if show_mean:
        mean_line = lists.mean(axis=0)
        plt.plot(x, mean_line, linewidth=3.0, marker="o")

    # optional shading (your regions)
    if shade_regions:
        plt.axvspan(0, 2 - 0.5, alpha=0.2)          # primacy-ish
        plt.axvspan(2 - 0.5, 7 - 0.5, alpha=0.2)
        plt.axvspan(7 - 0.5, 12 - 0.5, alpha=0.2)
        n = lists.shape[1]
        plt.axvspan(n - 3 - 0.5, n - 0.5, alpha=0.2)

    plt.xlabel("Serial Position")
    plt.ylabel("Item Value")
    plt.title(title)
    plt.tight_layout()
    plt.show()

# Random condition plot
plot_overlay(
    rand_complex_lists,
    title=f"Random (Complex): {num_lists} lists overlaid",
    alpha=0.05,   # lower = less clutter
    lw=1.0,
    show_mean=True
)

# Temporal condition plot
plot_overlay(
    temp_complex_lists,
    title=f"Temporal (Complex): {num_lists} lists overlaid",
    alpha=0.05,
    lw=1.0,
    show_mean=True
)

# %%
import numpy as np
import matplotlib.pyplot as plt

# ----------------------------
# Simulation
# ----------------------------
num_lists = 20
list_len = 15

temp_simple_lists = np.array(
    [ItemList(list_len, condition="Temporal", complex_temp=False).vals for _ in range(num_lists)]
)
temp_complex_lists = np.array(
    [ItemList(list_len, condition="Temporal", complex_temp=True).vals for _ in range(num_lists)]
)

x = np.arange(list_len)

# ----------------------------
# Helper: grid shape
# ----------------------------
def grid_shape(n):
    ncols = int(np.ceil(np.sqrt(n)))
    nrows = int(np.ceil(n / ncols))
    return nrows, ncols
def add_serial_position_shading(ax, n):
    # Primacy
    ax.axvspan(0, 2 - 0.5, color="green", alpha=0.2)
    # Early middle
    ax.axvspan(2 - 0.5, 7 - 0.5, color="magenta", alpha=0.2)
    # Late middle
    ax.axvspan(7 - 0.5, 12 - 0.5, color="yellow", alpha=0.2)
    # Recency
    ax.axvspan(n - 3 - 0.5, n - 0.5, color="red", alpha=0.2)


nrows, ncols = grid_shape(num_lists)

# ----------------------------
# Simple condition
# ----------------------------
fig, axes = plt.subplots(
    nrows, ncols,
    figsize=(3 * ncols, 2.5 * nrows),
    sharex=True, sharey=False
)
axes = axes.ravel()

for i in range(num_lists):
    y = temp_simple_lists[i]
    ax = axes[i]

    ax.plot(x, y, marker="o", linewidth=1)
    ax.axhline(y.mean(), linestyle="--", linewidth=1, alpha=0.8)  # ← mean line
    add_serial_position_shading(ax, n=list_len)
    ax.set_title(f"List {i+1}", fontsize=9)

for ax in axes[num_lists:]:
    ax.axis("off")

fig.suptitle("Temporal (New): Individual Lists", fontsize=14)
fig.supxlabel("Serial Position")
fig.supylabel("Item Value")
plt.tight_layout()
plt.show()

# ----------------------------
# Temporal condition
# ----------------------------
fig, axes = plt.subplots(
    nrows, ncols,
    figsize=(3 * ncols, 2.5 * nrows),
    sharex=True, sharey=False
)
axes = axes.ravel()

for i in range(num_lists):
    y = temp_complex_lists[i]
    ax = axes[i]

    ax.plot(x, y, marker="o", linewidth=1)
    ax.axhline(y.mean(), linestyle="--", linewidth=1, alpha=0.8)  # ← mean line
    add_serial_position_shading(ax, n=list_len)
    ax.set_title(f"List {i+1}", fontsize=9)

for ax in axes[num_lists:]:
    ax.axis("off")

fig.suptitle("Temporal (Old): Individual Lists", fontsize=14)
fig.supxlabel("Serial Position")
fig.supylabel("Item Value")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

conditions = {
    "Random Complex": rand_complex_list_means,
    "Temporal Complex": temp_complex_list_means,
}

num_conditions = len(conditions)
fig, axes = plt.subplots(num_conditions, 1, figsize=(12, 4 * num_conditions), sharex=True)

if num_conditions == 1:
    axes = [axes]  # ensure axes is iterable

for ax, (cond_name, list_means) in zip(axes, conditions.items()):
    mean_val = np.mean(list_means)
    std_val = np.std(list_means)
    
    # Plot list means
    ax.plot(list_means, label=f"{cond_name} (Mean={mean_val:.2f}, Std={std_val:.2f})", color='blue')
    
    ax.set_ylabel("Mean Value")
    ax.set_title(cond_name)
    ax.legend()

axes[-1].set_xlabel("List Index")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

conditions = {
    "Random": rand_list_means,
    "Temporal High First": temp_high_list_means,
    "Temporal Low First": temp_low_list_means
}

num_conditions = len(conditions)
fig, axes = plt.subplots(num_conditions, 1, figsize=(12, 4 * num_conditions), sharex=True)

if num_conditions == 1:
    axes = [axes]  # ensure axes is iterable

for ax, (cond_name, list_means) in zip(axes, conditions.items()):
    mean_val = np.mean(list_means)
    std_val = np.std(list_means)
    
    # Plot list means
    ax.plot(list_means, label=f"{cond_name} (Mean={mean_val:.2f}, Std={std_val:.2f})", color='blue')
    
    ax.set_ylabel("Mean Value")
    ax.set_title(cond_name)
    ax.legend()

axes[-1].set_xlabel("List Index")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

conditions = {
    "Random": rand_list_means,
    "Temporal High First": temp_high_list_means,
    "Temporal Low First": temp_low_list_means
}

num_conditions = len(conditions)
fig, axes = plt.subplots(num_conditions, 1, figsize=(12, 4 * num_conditions), sharex=True)

if num_conditions == 1:
    axes = [axes]  # ensure axes is iterable

for ax, (cond_name, list_means) in zip(axes, conditions.items()):
    mean_val = np.mean(list_means)
    std_val = np.std(list_means)
    
    # Plot list means
    ax.plot(list_means, label=f"{cond_name} (Mean={mean_val:.2f}, Std={std_val:.2f})", color='blue')
    
    ax.set_ylabel("Mean Value")
    ax.set_title(cond_name)
    ax.legend()

axes[-1].set_xlabel("List Index")
plt.tight_layout()
plt.show()

# %%
# Autocorrelation for a single list
def autocorr(x):
    x = np.array(x)
    n = len(x)
    ac = []
    for lag in range(n):
        if lag == 0:
            ac.append(np.nan)  # optional
        elif n-lag < 2 or np.std(x[:n-lag]) == 0 or np.std(x[lag:]) == 0:
            ac.append(0)  # cannot compute correlation
        else:
            ac.append(np.corrcoef(x[:n-lag], x[lag:])[0,1])
    return np.array(ac)

# Compute mean autocorrelation across all lists
def mean_autocorr(list_of_vals):
    ac_matrix = np.array([autocorr(vals) for vals in list_of_vals])
    return np.mean(ac_matrix, axis=0)  # signed mean

# # Temporal vs Random autocorr
# temporal_ac = mean_autocorr(temp_vals)
# random_ac = mean_autocorr(rand_vals)

# print(f"Mean auto correlation (Temporal): {np.nanmean(temporal_ac):.3f}")
# print(f"Mean auto correlation (Random): {np.nanmean(random_ac):.3f}")

# temporal_ac[0] = np.nan
# random_ac[0] = np.nan
# # Plot autocorrelation by lag
# plt.plot(random_ac, label="Random")
# plt.plot(temporal_ac, label="Temporal")
# plt.xlabel("Lag")
# plt.ylabel("Autocorrelation")
# plt.xlim([0,14])
# # plt.ylim([0,1])
# plt.title("Mean Signed Autocorrelation by Lag")
# plt.legend()
# plt.show()

# Consecutive correlation for a single list
# def consecutive_corr(vals):
#     return np.corrcoef(vals[:-1], vals[1:])[0,1]

# # # Compute mean consecutive correlation across lists
# # mean_consec_corr_temp = np.mean([consecutive_corr(vals) for vals in temp_vals])
# # mean_consec_corr_rand = np.mean([consecutive_corr(vals) for vals in rand_vals])

# print(f"Mean consecutive correlation (Temporal): {mean_consec_corr_temp:.3f}")
# print(f"Mean consecutive correlation (Random): {mean_consec_corr_rand:.3f}")

# %%
# Simulation parameters
n_lists = 5000
list_length = 15
lag_max = 14

# Independent variable: scaling factor for GP parameters
scales = np.arange(1, 7)  # 1x to 6x
avg_ac_by_scale = []

# Default GP parameter ranges
base_val_range = (0, 15)
base_mean_range = (4, 10)
base_var_range = (2, 6)

for scale in tqdm(scales, desc="Processing scales"):
    temp_vals = []
    # Scale the ranges proportionally
    scaled_gp_params = {
        "val_range": (base_val_range[0]*scale, base_val_range[1]*scale),
        "mean_range": (base_mean_range[0]*scale, base_mean_range[1]*scale),
        "var_range": (base_var_range[0]*scale, base_var_range[1]*scale),
        "decay_factor": 1.0,
        "effect_strength": 1.0
    }
    for _ in range(n_lists):
        lst = ItemList(length=list_length, condition="Temporal", complex_params=scaled_gp_params, complex_temp=True)
        temp_vals.append(lst.vals)
    avg_ac = mean_autocorr(temp_vals)
    avg_ac_by_scale.append(avg_ac)

avg_ac_by_scale = np.array(avg_ac_by_scale)

# Plot
plt.figure(figsize=(10,6))
for i, scale in enumerate(scales):
    plt.plot(range(lag_max+1), avg_ac_by_scale[i,:lag_max+1], label=f"Scale {scale}x")
plt.xlabel("Lag")
plt.ylabel("Mean Autocorrelation")
plt.title("Mean Autocorrelation by Lag for Different GP Parameter Scales")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-e54d3302221c> in <module>
#      13 base_var_range = (2, 6)
#      14
# ---> 15 for scale in tqdm(scales, desc="Processing scales"):
#      16     temp_vals = []
#      17     # Scale the ranges proportionally
#
# NameError: name 'tqdm' is not defined

# %%
# SIMPLE
n_lists = 5000
list_length = 15
lag_max = 14

# Independent variable: scaling factor for GP parameters
scales = np.arange(1, 7)  # 1x to 6x
avg_ac_by_scale = []

# Default GP parameter ranges
base_val_range = (0, 15)
base_mean_range = (4, 10)
base_var_range = (2, 6)

for scale in tqdm(scales, desc="Processing scales"):
    temp_vals = []
    # Scale the ranges proportionally
    scaled_gp_params = {
        "val_range": (base_val_range[0]*scale, base_val_range[1]*scale),
        "mean_range": (base_mean_range[0]*scale, base_mean_range[1]*scale),
        "var_range": (base_var_range[0]*scale, base_var_range[1]*scale),
        "decay_factor": 1.0,
        "effect_strength": 1.0
    }
    for _ in range(n_lists):
        lst = ItemList(length=list_length, condition="Temporal", complex_params=scaled_gp_params)
        temp_vals.append(lst.vals)
    avg_ac = mean_autocorr(temp_vals)
    avg_ac_by_scale.append(avg_ac)

avg_ac_by_scale = np.array(avg_ac_by_scale)

# Plot
plt.figure(figsize=(10,6))
for i, scale in enumerate(scales):
    plt.plot(range(lag_max+1), avg_ac_by_scale[i,:lag_max+1], label=f"Scale {scale}x")
plt.xlabel("Lag")
plt.ylabel("Mean Autocorrelation")
plt.title("Mean Autocorrelation by Lag for Different GP Parameter Scales")
plt.legend()
plt.show()

# %%
from tqdm import tqdm
# Simulation parameters
n_lists = 100
list_length = 15
lag_max = 14

# Independent variables
val_scales = np.arange(1, 7)            # scales for val_range
mean_var_scales = np.linspace(1, 3, 6)  # scales for mean_range
var_scales = np.linspace(1, 3, 6)       # scales for var_range

# Base GP parameter ranges
base_val_range = (0, 15)
base_mean_range = (4, 10)
base_var_range = (2, 6)

results = {}

for val_scale in tqdm(val_scales, desc="Processing val_scales"):
    ac_per_mean_var = {}
    
    for mean_scale in mean_var_scales:
        ac_per_var = []
        
        for var_scale in var_scales:
            # Scale val_range independently
            scaled_val_range = (base_val_range[0]*val_scale, base_val_range[1]*val_scale)

            # Scale mean_range and var_range
            scaled_mean_range = (base_mean_range[0]/mean_scale, base_mean_range[1]*mean_scale)
            scaled_var_range = (base_var_range[0]/var_scale, base_var_range[1]*var_scale)

            scaled_gp_params = {
                "val_range": scaled_val_range,
                "mean_range": scaled_mean_range,
                "var_range": scaled_var_range,
                "decay_factor": 1.0,
                "effect_strength": 1.0
            }

            # Generate lists
            temp_vals = []
            for _ in range(n_lists):
                lst = ItemList(length=list_length, condition="Temporal", gp_params=scaled_gp_params)
                temp_vals.append(lst.vals)
            
            avg_ac = mean_autocorr(temp_vals)
            ac_per_var.append(avg_ac)

        ac_per_mean_var[mean_scale] = np.array(ac_per_var)  # var_scales x lags

    results[val_scale] = ac_per_mean_var

# --- Plotting ---
for val_scale, mean_dict in results.items():
    for mean_scale, ac_matrix in mean_dict.items():
        plt.figure(figsize=(10, 6))
        for i, var_scale in enumerate(var_scales):
            plt.plot(range(lag_max+1), ac_matrix[i, :lag_max+1], label=f"var_scale {var_scale:.2f}")
        plt.xlabel("Lag")
        plt.ylabel("Autocorrelation")
        plt.title(f"Autocorrelation by Lag (val_scale={val_scale}, mean_scale={mean_scale:.2f})")
        plt.legend()
        plt.show()

# %%
subjects_dict = load_data('subjects_data.pkl')

# %%
subjects_dict['LTP564']

# %%
first_recall_probs = subjects_dict['LTP564']['first_recall_probs']
temporal_clustering = subjects_dict['LTP564']['temporal_clustering']
spatial_clustering = subjects_dict['LTP564']['spatial_clustering']
crp_probs = subjects_dict['LTP564']['crp_probs']

# %%
LTP564 = SimulatedSubjectData(subject='LTP564', first_recall=first_recall_probs, lag_crp=crp_probs, recall_rate=0.705, value_acc= 0.6)

# %%
pos = LTP564.generateLocations(r=1, n=len(LTP564.first_recall))
LTP564.generateLists(len(LTP564.first_recall), 3, wordpool=wordpool, pos=pos)

# %%
def addCRPProbsCheck(crp_dict):
    """
    Returns the sum of probabilities in a CRP dictionary and checks if it exceeds 1.

    Args:
        crp_dict (dict): CRP dictionary {lag: prob}.

    Returns:
        float: Sum of probabilities.

    Raises:
        ValueError: If total probability exceeds 1.
    """
    total_prob = sum(crp_dict.values())
    if total_prob > 1.0 + 1e-8:  # allow tiny floating point error
        raise ValueError(f"Total probability exceeds 1: {total_prob}")
    return total_prob

# %%
crp = LTP564.convertCRP(LTP564.lag_crp)
print(crp)

# %%
addCRPProbsCheck(crp)

# %%
addCRPProbsCheck(crp)

# %%
item_list1 = LTP564.item_lists[0]
proc = ItemProcessor(item_list1)

# %%
proc.hasItems()

# %%
crp = LTP564.convertCRP(LTP564.lag_crp)
item, val, pos, serialpos = proc.pickFirstItem(first_recall_probs)

# %%
first_recall_probs

# %%
proc.pickItem(crp, serialpos)

# %%
LTP564.generateData(list_len=15,num_lists=2, wordpool=wordpool, gen_pos=True, guess_by_subset=True, reset=True)
