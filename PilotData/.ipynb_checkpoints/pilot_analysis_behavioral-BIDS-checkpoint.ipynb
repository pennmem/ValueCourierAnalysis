# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
import sys
sys.path.append('../../pybeh')
sys.path.append('../../CourierReinstate1')
import cmlreaders as cml
from cmldask import CMLDask as da
from dask.distributed import wait, as_completed
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.colors as mcolors
import seaborn as sns
import pandas as pd
import xarray as xr
import pandas_to_pybeh as pb
import scipy as scp
import re
import math
import pickle
import gc
from scipy import stats
from ptsa.data.filters import ButterworthFilter, MorletWaveletFilter
from statsmodels.stats.multitest import multipletests
# from compute_scalp_features import create_baseline_events
from BehavioralFunctions import *
from mne_bids import BIDSPath, read_raw_bids
pd.options.display.max_rows = 100
pd.options.display.max_columns = 50
# %matplotlib inline
import importlib
import statsmodels.api as sm
from statsmodels.stats.anova import AnovaRM

# %%
subjects = ['LTP606', 'LTP607', 'LTP609', 'LTP610', 'LTP612']
bids_root = "/home1/maint/LTP_BIDS/"
exp = "valuecourier"

# %%
# get full events
full_evs = None
for sub in subjects:
    for session in range(6):
        try:
            bids_path = BIDSPath(
                subject=sub,
                session=str(session),
                task=exp,  
                datatype="beh",
                extension=".tsv",
                root=bids_root
            )
            evs = pd.read_csv(bids_path.fpath, sep="\t")
            full_evs = evs if full_evs is None else pd.concat([full_evs, evs], ignore_index=True)
        except Exception as e:
            print(e)
full_evs
cols = ["primacybuf", "recencybuf", "serialpos"]

for c in cols:
    full_evs[c] = (
        pd.to_numeric(full_evs[c], errors="coerce")  # make sure it's numeric, NaNs stay NaN
        .astype("Int64")                             # pandas nullable integer dtype
    )
# Out:
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP607/ses-0/beh/sub-LTP607_ses-0_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP607/ses-1/beh/sub-LTP607_ses-1_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP607/ses-2/beh/sub-LTP607_ses-2_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP607/ses-3/beh/sub-LTP607_ses-3_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP607/ses-4/beh/sub-LTP607_ses-4_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP607/ses-5/beh/sub-LTP607_ses-5_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP609/ses-0/beh/sub-LTP609_ses-0_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP609/ses-1/beh/sub-LTP609_ses-1_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP609/ses-2/beh/sub-LTP609_ses-2_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP609/ses-3/beh/sub-LTP609_ses-3_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP609/ses-4/beh/sub-LTP609_ses-4_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP609/ses-5/beh/sub-LTP609_ses-5_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP610/ses-0/beh/sub-LTP610_ses-0_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP610/ses-1/beh/sub-LTP610_ses-1_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP610/ses-2/beh/sub-LTP610_ses-2_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP610/ses-3/beh/sub-LTP610_ses-3_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP610/ses-4/beh/sub-LTP610_ses-4_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP610/ses-5/beh/sub-LTP610_ses-5_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP612/ses-0/beh/sub-LTP612_ses-0_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP612/ses-1/beh/sub-LTP612_ses-1_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP612/ses-2/beh/sub-LTP612_ses-2_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP612/ses-3/beh/sub-LTP612_ses-3_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP612/ses-4/beh/sub-LTP612_ses-4_task-valuecourier'
# [Errno 2] No such file or directory: '/home1/maint/LTP_BIDS/sub-LTP612/ses-5/beh/sub-LTP612_ses-5_task-valuecourier'

# %%
# Convert to DataFrame
value_recalls = full_evs[full_evs.trial_type == "VALUE_RECALL"] 
words = full_evs[full_evs.trial_type == "WORD"]
rec_words = full_evs[full_evs.trial_type == "REC_WORD"]
rec_vv_words = full_evs[full_evs.trial_type == "REC_WORD_VV"]

# WORD --> storepointtype, recalled--> VALUE_RECALL, REC_WORD, REC_WORD_VV
word_trial_to_storepointtype = words.set_index("trial")["storepointtype"].to_dict()
word_trial_to_recalled = words.set_index("trial")["recalled"].to_dict()
for event_type in ["VALUE_RECALL", "REC_WORD", "REC_WORD_VV"]:
    subset = full_evs[full_evs.trial_type == event_type]
    for idx, row in subset.iterrows():
        trial = row["trial"]
        if trial in word_trial_to_storepointtype:
            full_evs.at[idx, "storepointtype"] = word_trial_to_storepointtype[trial]
        if trial in word_trial_to_recalled:
            full_evs.at[idx, "recalled"] = word_trial_to_recalled[trial]

# VALUE_RECALL --> actualvalue, valuerecall --> WORD, `REC_WORD`, REC_WORD_VV
valuerecall_trial_to_actualvalue = value_recalls.set_index("trial")["actualvalue"].to_dict()
valuerecall_trial_to_valuerecall = value_recalls.set_index("trial")["valuerecall"].to_dict()

# --- Apply to multi-row event types ---
for event_type in ["WORD", "REC_WORD", "REC_WORD_VV"]:
    subset = full_evs[full_evs.trial_type == event_type]
    for idx, row in subset.iterrows():
        trial = row["trial"]

        # actualvalue
        if trial in valuerecall_trial_to_actualvalue:
            full_evs.at[idx, "actualvalue"] = valuerecall_trial_to_actualvalue[trial]

        # valuerecall
        if trial in valuerecall_trial_to_valuerecall:
            full_evs.at[idx, "valuerecall"] = valuerecall_trial_to_valuerecall[trial]

# %%
with open("all_items.txt") as f:
    pool_raw = [w.strip() for w in f if w.strip()]
if pool_raw and pool_raw[0].lower() == "word":
    pool_raw = pool_raw[1:]

pool = [w.upper() for w in pool_raw]
pool_map = {w: i+1 for i, w in enumerate(pool)}

full_evs["itemno"] = full_evs["item"].map(pool_map)

# %% [markdown]
# ### Behavioral

# %%
# Overall recall probability

pres = full_evs.trial_type=='WORD'
recall_by_sub = full_evs[pres].groupby('subject')\
    .agg({'recalled':'mean'})\
    .rename(columns={"recalled":"Recall_Probability"}
)
recall_by_sub = recall_by_sub.reset_index()
recall_by_sub = recall_by_sub.sort_values(by="Recall_Probability", ascending=True)
sub_recall = recall_by_sub.subject.values
recall_by_sub
# Out:
#   subject  Recall_Probability
# 0  LTP606             0.24183

# %%
print(f"Mean = {recall_by_sub['Recall_Probability'].mean()}, SD = {recall_by_sub['Recall_Probability'].std()}")
# Out:
# Mean = 0.24183006535947713, SD = nan

# %%
# SPC

spc_df = full_evs.query("trial_type=='WORD'").groupby(
    ['subject', 'session', 'serialpos']
).agg({'recalled':np.nanmean}).reset_index()

avg_spc_df = spc_df.groupby(["subject","serialpos"]).agg({"recalled":"mean"}).reset_index()

# %%
fig = plt.figure(figsize=(8, 6))
ax = plt.gca()

colors = sns.light_palette("#79B", len(sub_recall))
for i, sub in enumerate(sub_recall):
    sub_df = avg_spc_df.query('subject == @sub')
    sub_spc = sns.pointplot(data=sub_df, x='serialpos', y='recalled', ci=None, ax=ax, color=colors[i])
    
spc = sns.pointplot(data=avg_spc_df, x='serialpos', y='recalled', ci=68, capsize=.3, ax=ax, color="k")

plt.title('Serial Position Curve', fontsize=24)
plt.xlabel('Serial Position', fontsize=22)
plt.ylabel('Recall Probability', fontsize=22)
plt.tick_params(labelsize=18)
plt.ylim(0, 1.1)
spc.yaxis.grid()
plt.tight_layout()
ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)
plt.show()

# %%
# for key, grp in first_recall_df.groupby(['subject', 'serialpos']):
#     print("\nGroup key:", key)
#     print(grp.head())

# %%
# recword = full_evs.query('trial_type=="REC_WORD"')
# recword['pos'] = recword.groupby(['subject', 'session', 'trial']).cumcount()
# mask = (recword['pos'] == 0) & recword['serialpos'].notna()
# first_recall_df = recword.loc[mask]
# first_recall_df.groupby(
#     ['subject', 'serialpos']).agg(
#     {'recalled': 'count'}).unstack(fill_value=0).stack().reset_index()

# %%
# Probability of first recall

recword = full_evs.query('trial_type=="REC_WORD"')
recword['pos'] = recword.groupby(['subject', 'session', 'trial']).cumcount()
first_recall_df = recword.query('pos == 0').query('serialpos.notnull()')
first_recall_df = first_recall_df.groupby(
    ['subject', 'serialpos']).agg(
    {'recalled': 'count'}).unstack(fill_value=0).stack().reset_index()
first_recall_df['n_lists'] = first_recall_df.groupby(['subject'])['recalled'].transform('sum')
first_recall_df['prob'] = first_recall_df['recalled'] / first_recall_df['n_lists']
first_recall_df
# Out:
#    subject  serialpos  recalled  n_lists      prob
# 0   LTP606          1         3       48  0.062500
# 1   LTP606          3         4       48  0.083333
# 2   LTP606          4         1       48  0.020833
# 3   LTP606          5         3       48  0.062500
# 4   LTP606          6         1       48  0.020833
# 5   LTP606          7         3       48  0.062500
# 6   LTP606          8         1       48  0.020833
# 7   LTP606          9         1       48  0.020833
# 8   LTP606         10         5       48  0.104167
# 9   LTP606         11         2       48  0.041667
# 10  LTP606         12         3       48  0.062500
# 11  LTP606         13         6       48  0.125000
# 12  LTP606         14         6       48  0.125000
# 13  LTP606         15         9       48  0.187500

# %%
fig = plt.figure(figsize=(8, 6))
ax = plt.gca()

colors = sns.light_palette("#79B", len(sub_recall))
for i, sub in enumerate(sub_recall):
    sub_df = first_recall_df.query('subject == @sub')
    sub_spc = sns.pointplot(data=sub_df, x='serialpos', y='prob', ci=None, ax=ax, color=colors[len(colors)-i-1])

spc = sns.pointplot(data=first_recall_df, x='serialpos', y='prob', ci=68, capsize=.3, ax=ax, color="k")

plt.title('Probability of First Recall', fontsize=24)
plt.xlabel('Serial Position', fontsize=22)
plt.ylabel('Recall Probability', fontsize=22)
plt.tick_params(labelsize=18)
plt.ylim(0, 1.01)
plt.tight_layout()
ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)
spc.yaxis.grid()
plt.show()

# %%
# Lag CRP

rec_word_types_all = ['REC_WORD', 'REC_WORD_VV']
present_types = set(full_evs['trial_type'].unique())
present_rec_types = [t for t in rec_word_types_all if t in present_types]

need_types = ['WORD'] + present_rec_types
clean_evs = full_evs[full_evs['trial_type'].isin(need_types)].copy()

for t in present_rec_types:
    if t != 'REC_WORD':
        clean_evs.loc[clean_evs['trial_type'] == t, 'trial_type'] = 'REC_WORD'

is_word = clean_evs['trial_type'].eq('WORD')
is_rec  = clean_evs['trial_type'].eq('REC_WORD')

temporal_evs = clean_evs[~(is_word & clean_evs['itemno'].isna())].copy()
temporal_evs.loc[is_rec, 'itemno'] = temporal_evs.loc[is_rec, 'itemno'].fillna(0)

temporal_evs['itemno'] = (
    pd.to_numeric(temporal_evs['itemno'], errors='coerce')
    .astype('Int64')  # note the capital I
)
temporal_evs
# Out:
#        mstime trial_type                            stim_file  actualvalue  \
# 68    2287892       WORD  wordpools/valuecourier_wordpool.txt    22.933332
# 70    2352924       WORD  wordpools/valuecourier_wordpool.txt    22.933332
# 71    2375559       WORD  wordpools/valuecourier_wordpool.txt    22.933332
# 73    2437993       WORD  wordpools/valuecourier_wordpool.txt    22.933332
# 74    2454991       WORD  wordpools/valuecourier_wordpool.txt    22.933332
# ...       ...        ...                                  ...          ...
# 1702  2530909       WORD  wordpools/valuecourier_wordpool.txt    10.133333
# 1703  2557592       WORD  wordpools/valuecourier_wordpool.txt    10.133333
# 1704  2577009       WORD  wordpools/valuecourier_wordpool.txt    10.133333
# 1711  2623994   REC_WORD  wordpools/valuecourier_wordpool.txt    10.133333
# 1712  2639829   REC_WORD  wordpools/valuecourier_wordpool.txt    10.133333
#
#       compensation                                            eegfile  \
# 68        8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 70        8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 71        8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 73        8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# 74        8.461538  /protocols/ltp/subjects/LTP606/experiments/Val...
# ...            ...                                                ...
# 1702           NaN  /protocols/ltp/subjects/LTP606/experiments/Val...
# 1703           NaN  /protocols/ltp/subjects/LTP606/experiments/Val...
# 1704           NaN  /protocols/ltp/subjects/LTP606/experiments/Val...
# 1711           NaN  /protocols/ltp/subjects/LTP606/experiments/Val...
# 1712           NaN  /protocols/ltp/subjects/LTP606/experiments/Val...
#
#       eogArtifact    experiment  intruded  intrusion       item  itemno  \
# 68              3  ValueCourier       0.0        NaN      JEANS     115
# 70              3  ValueCourier       0.0        NaN  WATER_GUN     232
# 71              3  ValueCourier       0.0        NaN      LIGHT     122
# 73              3  ValueCourier       0.0        NaN     PEARLS     154
# 74              3  ValueCourier       0.0        NaN    NAILGUN     138
# ...           ...           ...       ...        ...        ...     ...
# 1702            3  ValueCourier       0.0        NaN    OREGANO     149
# 1703            3  ValueCourier       0.0        NaN      SYRUP     212
# 1704            3  ValueCourier       0.0        NaN  WATER_GUN     232
# 1711           -1  ValueCourier       NaN        0.0    ORCHIDS     148
# 1712           -1  ValueCourier       NaN        0.0    HAMSTER     105
#
#       itemvalue  montage  msoffset  multiplier  numingroupchosen phase  \
# 68         10.0        0        -1    0.846154               4.0     1
# 70         13.0        0        -1    0.846154               4.0     1
# 71         22.0        0        -1    0.846154               4.0     1
# 73         22.0        0        -1    0.846154               4.0     1
# 74         16.0        0        -1    0.846154               4.0     1
# ...         ...      ...       ...         ...               ...   ...
# 1702        7.0        0        -1         NaN               4.0     1
# 1703       16.0        0        -1         NaN               4.0     1
# 1704       20.0        0        -1         NaN               4.0     1
# 1711        NaN        0        20         NaN               NaN     1
# 1712        NaN        0        20         NaN               NaN     1
#
#       playerrotY       presX       presZ  primacybuf protocol  recalled  \
# 68     84.570000   56.968750   81.750000           2      ltp       1.0
# 70    103.199997  -33.375000  -83.812500           2      ltp       1.0
# 71    206.360001   22.296875  -51.375000           2      ltp       0.0
# 73      2.900000  -42.531250   61.000000           2      ltp       0.0
# 74     77.989998   -6.160156  125.750000           2      ltp       1.0
# ...          ...         ...         ...         ...      ...       ...
# 1702  352.640015  102.375000   51.843750           2      ltp       0.0
# 1703  170.919998 -107.062500  -30.500000           2      ltp       0.0
# 1704  219.110001  -34.843750  -83.875000           2      ltp       0.0
# 1711         NaN   -3.544922    9.984375        <NA>      ltp       0.0
# 1712         NaN   -3.544922    9.984375        <NA>      ltp       0.0
#
#       rectime  recencybuf  serialpos  session           store      storeX  \
# 68        NaN           3          1        0  clothing_store   56.718750
# 70        NaN           3          2        0       toy_store  -29.187500
# 71        NaN           3          3        0       bike_shop   18.671875
# 73        NaN           3          4        0   jewelry_store  -37.500000
# 74        NaN           3          5        0  hardware_store   -8.867188
# ...       ...         ...        ...      ...             ...         ...
# 1702      NaN           3         13        5        pizzeria   98.687500
# 1703      NaN           3         14        5            cafe -112.062500
# 1704      NaN           3         15        5       toy_store  -29.187500
# 1711   3019.0        <NA>          4        5         florist  140.750000
# 1712  18854.0        <NA>          8        5       pet_store   93.562500
#
#           storeZ storepointtype subject  trial  valuerecall
# 68     77.937500       Temporal  LTP606      0         23.0
# 70    -93.875000       Temporal  LTP606      0         23.0
# 71    -51.718750       Temporal  LTP606      0         23.0
# 73     61.000000       Temporal  LTP606      0         23.0
# 74    131.875000       Temporal  LTP606      0         23.0
# ...          ...            ...     ...    ...          ...
# 1702   51.812500       Temporal  LTP606      5         10.0
# 1703  -30.484375       Temporal  LTP606      5         10.0
# 1704  -93.875000       Temporal  LTP606      5         10.0
# 1711   60.593750       Temporal  LTP606      5         10.0
# 1712   -7.761719       Temporal  LTP606      5         10.0
#
# [994 rows x 35 columns]

# %%
crp_df = temporal_evs.groupby(['subject']).apply(
    pb.pd_crp,
    itemno_column='itemno',
    list_index=['subject', 'session', 'trial'],
    lag_num=14,type_column="trial_type").reset_index()

# %%
crp_df
# Out:
#    subject  level_1      prob  lag
# 0   LTP606      -14  0.166667  -14
# 1   LTP606      -13  0.166667  -13
# 2   LTP606      -12  0.200000  -12
# 3   LTP606      -11  0.000000  -11
# 4   LTP606      -10  0.042553  -10
# 5   LTP606       -9  0.071429   -9
# 6   LTP606       -8  0.071429   -8
# 7   LTP606       -7  0.000000   -7
# 8   LTP606       -6  0.044776   -6
# 9   LTP606       -5  0.125000   -5
# 10  LTP606       -4  0.050633   -4
# 11  LTP606       -3  0.072289   -3
# 12  LTP606       -2  0.089888   -2
# 13  LTP606       -1  0.079545   -1
# 14  LTP606        0       NaN    0
# 15  LTP606        1  0.153846    1
# 16  LTP606        2  0.076923    2
# 17  LTP606        3  0.089552    3
# 18  LTP606        4  0.064516    4
# 19  LTP606        5  0.094340    5
# 20  LTP606        6  0.098039    6
# 21  LTP606        7  0.086957    7
# 22  LTP606        8  0.081081    8
# 23  LTP606        9  0.027778    9
# 24  LTP606       10  0.000000   10
# 25  LTP606       11  0.095238   11
# 26  LTP606       12  0.153846   12
# 27  LTP606       13  0.000000   13
# 28  LTP606       14  0.000000   14

# %%
fig = plt.figure(figsize=(12, 6))
fig.patch.set_facecolor('white')
ax = plt.gca()

from matplotlib.colors import ListedColormap

colors = sns.light_palette("#79B", len(sub_recall))
for i, sub in enumerate(sub_recall):
    sub_crp = crp_df.query('subject == @sub')
    sns.pointplot(data=sub_crp, x="lag", y="prob", 
                  color= colors[i], 
                  ax=ax,
                  linestyles="-")
 
crp = sns.pointplot(data=crp_df, x='lag', y='prob', ci=68,
                    color='k', capsize=.2, ax=ax)

ax.set_title('Lag CRP', fontsize=24)
ax.set_xlabel('Lag', fontsize=22)
ax.set_ylabel('Conditional Response Probability', fontsize=22)
ax.tick_params(labelsize=18)
plt.ylim([0,1.01])
ax.yaxis.grid()
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

plt.tight_layout()
plt.show()

# %%
# Temporal clustering score

temporal_clustering_df = compute_temporal_clustering(temporal_evs, type_column="type_trial")
temporal_clustering_df
# Out:
#   subject        TC
# 0  LTP606  0.527796

# %%
# Error plots

merged_df = get_mixed_model_fitted_error(temporal_evs, recall_by_sub,type_column="trial_type")
plot_error_diff_vs_binned_cluster_score(merged_df)
# Out:
#    subject  session  trial  actualvalue  valuerecall  item_count  \
# 0   LTP606        0      0    22.933332         23.0          15
# 1   LTP606        0      1    16.933332         17.0          15
# 2   LTP606        0      2    11.200000         11.0          15
# 3   LTP606        0      3    32.000000         36.0          15
# 4   LTP606        0      4    24.933332         24.0          15
# 5   LTP606        1      0    22.933332         23.0          15
# 6   LTP606        1      1    16.933332         17.0          15
# 7   LTP606        1      2    11.200000         11.0          15
# 8   LTP606        1      3    32.000000         36.0          15
# 9   LTP606        1      4    24.933332         24.0          15
# 10  LTP606        1      5    10.133333         10.0          15
# 11  LTP606        1      6    30.000000         30.0          15
# 12  LTP606        1      7    25.000000         25.0          15
# 13  LTP606        1      8    10.133333         10.0          15
# 14  LTP606        1      9    38.666668         39.0          15
# 15  LTP606        2      0    22.933332         23.0          15
# 16  LTP606        2      1    16.933332         17.0          15
# 17  LTP606        2      2    11.200000         11.0          15
# 18  LTP606        2      3    32.000000         36.0          15
# 19  LTP606        2      4    24.933332         24.0          15
# 20  LTP606        2      5    10.133333         10.0          15
# 21  LTP606        2      6    30.000000         30.0          15
# 22  LTP606        2      7    25.000000         25.0          15
# 23  LTP606        2      8    10.133333         10.0          15
# 24  LTP606        2      9    38.666668         39.0          15
# 25  LTP606        3      0    22.933332         23.0          15
# 26  LTP606        3      1    16.933332         17.0          15
# 27  LTP606        3      2    11.200000         11.0          15
# 28  LTP606        3      3    32.000000         36.0          15
# 29  LTP606        3      4    24.933332         24.0          15
# 30  LTP606        3      5    10.133333         10.0          15
# 31  LTP606        3      6    30.000000         30.0          15
# 32  LTP606        3      7    25.000000         25.0          15
# 33  LTP606        3      8    10.133333         10.0          15
# 34  LTP606        3      9    38.666668         39.0          15
# 35  LTP606        4      0    22.933332         23.0          15
# 36  LTP606        4      1    16.933332         17.0          15
# 37  LTP606        4      2    11.200000         11.0          15
# 38  LTP606        4      3    32.000000         36.0          15
# 39  LTP606        4      4    24.933332         24.0          15
# 40  LTP606        4      5    10.133333         10.0          15
# 41  LTP606        4      6    30.000000         30.0          15
# 42  LTP606        4      7    25.000000         25.0          15
# 43  LTP606        4      8    10.133333         10.0          15
# 44  LTP606        4      9    38.666668         39.0          15
# 45  LTP606        5      0    22.933332         23.0          15
# 46  LTP606        5      1    16.933332         17.0          15
# 47  LTP606        5      2    11.200000         11.0          15
# 48  LTP606        5      3    32.000000         36.0          15
# 49  LTP606        5      4    24.933332         24.0          15
# 50  LTP606        5      5    10.133333         10.0          15
#
#    storepointtype  abs_error
# 0        Temporal   0.066668
# 1        Temporal   0.066668
# 2          random   0.200000
# 3          random   4.000000
# 4        Temporal   0.933332
# 5        Temporal   0.066668
# 6          random   0.066668
# 7          random   0.200000
# 8          random   4.000000
# 9        Temporal   0.933332
# 10       Temporal   0.133333
# 11         random   0.000000
# 12         random   0.000000
# 13       Temporal   0.133333
# 14       Temporal   0.333332
# 15       Temporal   0.066668
# 16         random   0.066668
# 17         random   0.200000
# 18         random   4.000000
# 19       Temporal   0.933332
# 20       Temporal   0.133333
# 21       Temporal   0.000000
# 22       Temporal   0.000000
# 23         random   0.133333
# 24         random   0.333332
# 25         random   0.066668
# 26         random   0.066668
# 27         random   0.200000
# 28       Temporal   4.000000
# 29         random   0.933332
# 30       Temporal   0.133333
# 31       Temporal   0.000000
# 32       Temporal   0.000000
# 33       Temporal   0.133333
# 34       Temporal   0.333332
# 35         random   0.066668
# 36       Temporal   0.066668
# 37         random   0.200000
# 38       Temporal   4.000000
# 39         random   0.933332
# 40         random   0.133333
# 41       Temporal   0.000000
# 42         random   0.000000
# 43       Temporal   0.133333
# 44       Temporal   0.333332
# 45       Temporal   0.066668
# 46         random   0.066668
# 47         random   0.200000
# 48       Temporal   4.000000
# 49         random   0.933332
# 50       Temporal   0.133333
# abs_error             0
# storepointtype        0
# TC                    0
# Recall_Probability    0
# subject               0
# dtype: int64
# N rows in merged: 51
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[43], line 3
#       1 # Error plots
# ----> 3 merged_df = get_mixed_model_fitted_error(temporal_evs, recall_by_sub,type_column="trial_type")
#       4 plot_error_diff_vs_binned_cluster_score(merged_df)
#
# File ~/ValueCourierAnalysis/PilotData/BehavioralFunctions.py:303, in get_mixed_model_fitted_error(in_df, recall_by_sub, type_column)
#     300 merged = merge_predictors(error_by_trial, temporal_clustering_df, recall_by_sub)
#     302 # Step 4
# --> 303 merged = fit_models_and_get_residuals(merged)
#     305 # Step 5
#     306 error_wide_adj = compute_error_diff_adj(merged)
#
# File ~/ValueCourierAnalysis/PilotData/BehavioralFunctions.py:253, in fit_models_and_get_residuals(merged)
#     246 print("N rows in merged:", len(merged))
#     248 model = smf.mixedlm(
#     249     "abs_error ~ storepointtype + TC + Recall_Probability",
#     250     data=merged,
#     251     groups=merged["subject"]
#     252 )
# --> 253 result = model.fit(reml=False)
#     254 print(result.summary())
#     256 # Fit simple OLS for recall correction
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2192, in MixedLM.fit(self, start_params, reml, niter_sa, do_cg, fe_pen, cov_pen, free, full_output, method, **fit_kwargs)
#    2190 # Try optimizing one or more times
#    2191 for j in range(len(method)):
# -> 2192     rslt = super(MixedLM, self).fit(start_params=packed,
#    2193                                     skip_hessian=True,
#    2194                                     method=method[j],
#    2195                                     **fit_kwargs)
#    2196     if rslt.mle_retvals['converged']:
#    2197         break
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/statsmodels/base/model.py:566, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     563     del kwargs["use_t"]
#     565 optimizer = Optimizer()
# --> 566 xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     567                                                fargs, kwargs,
#     568                                                hessian=hess,
#     569                                                method=method,
#     570                                                disp=disp,
#     571                                                maxiter=maxiter,
#     572                                                callback=callback,
#     573                                                retall=retall,
#     574                                                full_output=full_output)
#     575 # Restore cov_type, cov_kwds and use_t
#     576 optim_settings.update(kwds)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/statsmodels/base/optimizer.py:242, in Optimizer._fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     239     fit_funcs.update(extra_fit_funcs)
#     241 func = fit_funcs[method]
# --> 242 xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     243                      disp=disp, maxiter=maxiter, callback=callback,
#     244                      retall=retall, full_output=full_output,
#     245                      hess=hessian)
#     247 optim_settings = {'optimizer': method, 'start_params': start_params,
#     248                   'maxiter': maxiter, 'full_output': full_output,
#     249                   'disp': disp, 'fargs': fargs, 'callback': callback,
#     250                   'retall': retall, "extra_fit_funcs": extra_fit_funcs}
#     251 optim_settings.update(kwargs)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/statsmodels/base/optimizer.py:537, in _fit_bfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     535 norm = kwargs.setdefault('norm', np.Inf)
#     536 epsilon = kwargs.setdefault('epsilon', 1.4901161193847656e-08)
# --> 537 retvals = optimize.fmin_bfgs(f, start_params, score, args=fargs,
#     538                              gtol=gtol, norm=norm, epsilon=epsilon,
#     539                              maxiter=maxiter, full_output=full_output,
#     540                              disp=disp, retall=retall, callback=callback)
#     541 if full_output:
#     542     if not retall:
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/scipy/optimize/_optimize.py:1360, in fmin_bfgs(f, x0, fprime, args, gtol, norm, epsilon, maxiter, full_output, disp, retall, callback, xrtol)
#    1351 opts = {'gtol': gtol,
#    1352         'norm': norm,
#    1353         'eps': epsilon,
#    (...)
#    1356         'return_all': retall,
#    1357         'xrtol': xrtol}
#    1359 callback = _wrap_callback(callback)
# -> 1360 res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#    1362 if full_output:
#    1363     retlist = (res['x'], res['fun'], res['jac'], res['hess_inv'],
#    1364                res['nfev'], res['njev'], res['status'])
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/scipy/optimize/_optimize.py:1445, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, **unknown_options)
#    1442 pk = -np.dot(Hk, gfk)
#    1443 try:
#    1444     alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 1445              _line_search_wolfe12(f, myfprime, xk, pk, gfk,
#    1446                                   old_fval, old_old_fval, amin=1e-100, amax=1e100)
#    1447 except _LineSearchError:
#    1448     # Line search failed to find a better solution.
#    1449     warnflag = 2
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/scipy/optimize/_optimize.py:1215, in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#    1201 """
#    1202 Same as line_search_wolfe1, but fall back to line_search_wolfe2 if
#    1203 suitable step length is not found, and raise an exception if a
#    (...)
#    1210
#    1211 """
#    1213 extra_condition = kwargs.pop('extra_condition', None)
# -> 1215 ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1216                          old_fval, old_old_fval,
#    1217                          **kwargs)
#    1219 if ret[0] is not None and extra_condition is not None:
#    1220     xp1 = xk + ret[0] * pk
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:84, in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      80     return np.dot(gval[0], pk)
#      82 derphi0 = np.dot(gfk, pk)
# ---> 84 stp, fval, old_fval = scalar_search_wolfe1(
#      85         phi, derphi, old_fval, old_old_fval, derphi0,
#      86         c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#      88 return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:160, in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     158 if task[:2] == b'FG':
#     159     alpha1 = stp
# --> 160     phi1 = phi(stp)
#     161     derphi1 = derphi(stp)
#     162 else:
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/scipy/optimize/_linesearch.py:75, in line_search_wolfe1.<locals>.phi(s)
#      73 def phi(s):
#      74     fc[0] += 1
# ---> 75     return f(xk + s*pk, *args)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:267, in ScalarFunction.fun(self, x)
#     265 if not np.array_equal(x, self.x):
#     266     self._update_x_impl(x)
# --> 267 self._update_fun()
#     268 return self.f
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/statsmodels/base/model.py:534, in LikelihoodModel.fit.<locals>.f(params, *args)
#     533 def f(params, *args):
# --> 534     return -self.loglike(params, *args) / nobs
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:1499, in MixedLM.loglike(self, params, profile_fe)
#    1497 # Move to the profile set
#    1498 if profile_fe:
# -> 1499     fe_params, sing = self.get_fe_params(cov_re, vcomp)
#    1500     if sing:
#    1501         self._cov_sing += 1
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:1346, in MixedLM.get_fe_params(self, cov_re, vcomp, tol)
#    1344     fe_params = np.dot(np.linalg.pinv(xtxy[:, 0:-1]), xtxy[:, -1])
#    1345 else:
# -> 1346     fe_params = np.linalg.solve(xtxy[:, 0:-1], xtxy[:, -1])
#    1348 return fe_params, sing
#
# File <__array_function__ internals>:200, in solve(*args, **kwargs)
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/numpy/linalg/linalg.py:386, in solve(a, b)
#     384 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     385 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 386 r = gufunc(a, b, signature=signature, extobj=extobj)
#     388 return wrap(r.astype(result_t, copy=False))
#
# File /usr/global/miniconda/py310_23.1.0-1/envs/workshop_311/lib/python3.11/site-packages/numpy/linalg/linalg.py:89, in _raise_linalgerror_singular(err, flag)
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
sub_error_df = get_mixed_model_fitted_error_conditions(temporal_evs)
sub_error_df

# %%
plot_error_vs_cluster_score_conditions(sub_error_df)

# %%
experiment = 'ValueCourier'
data = cml.get_data_index(kind = 'ltp')
data = data[(data['experiment']==experiment)].sort_values('session').reset_index()

full_evs = None
for i, row in data.iterrows():
    # intialize data reader, load words events and buffered eeg epochs
    r = cml.CMLReader(subject=row['subject'], experiment=row['experiment'], session=row['session'])
    evs = r.load('task_events')
    full_evs = evs if full_evs is None else pd.concat([full_evs, evs], ignore_index=True)
full_evs = full_evs.query('subject in @subjects')
full_evs

# %%
cml.CMLReader(subject="LTP606", experiment=experiment, session=3).load('task_events')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# ---------------------------------------------------
# 1. Trial-level errors → session-level mean error
# ---------------------------------------------------
error_by_trial = compute_trial_error_conditions(full_evs)

sub_error = (
    error_by_trial
    .groupby(['subject', 'session'], as_index=False)
    .agg(
        err_all=('error_all', 'mean'),
        err_middle=('error_middle', 'mean'),
        err_correct=('error_correct', 'mean'),
        err_corr_mid=('error_corr_mid', 'mean'),
    )
)

# ---------------------------------------------------
# 2. Compensation per subject × session
# ---------------------------------------------------
rows = []

for sub in subjects:
    for sess in range(6):
        subset = full_evs[(full_evs.subject == sub) & (full_evs.session == sess)]
        if subset.empty:
            continue

        comp = subset.iloc[0].compensation
        if comp >= 0:
            rows.append({"subject": sub, "session": sess, "compensation": comp})

df_comp = pd.DataFrame(rows).sort_values(["subject", "session"])

# ---------------------------------------------------
# 3. Merge compensation + error (use err_all)
# ---------------------------------------------------
df = pd.merge(df_comp, sub_error[["subject", "session", "err_all"]],
              on=["subject", "session"], how="inner")

# ---------------------------------------------------
# 4. REMOVE subjects with only 1 session
# ---------------------------------------------------
counts = df.groupby("subject")["session"].nunique()
subjects_keep = counts[counts > 1].index

df = df[df["subject"].isin(subjects_keep)]

print("Subjects kept (≥2 sessions):", list(subjects_keep))

# ---------------------------------------------------
# 5. Plot – twin axes: compensation vs mean error_all
# ---------------------------------------------------
fig, ax1 = plt.subplots(figsize=(14, 8))
ax2 = ax1.twinx()

subjects_plot = sorted(df["subject"].unique())
colors = plt.cm.tab10(np.linspace(0, 1, len(subjects_plot)))

for color, sub in zip(colors, subjects_plot):
    df_sub = df[df["subject"] == sub].sort_values("session")

    # Left axis: compensation
    ax1.plot(
        df_sub["session"],
        df_sub["compensation"],
        marker="o",
        linestyle="-",
        linewidth=4,
        color=color,
        label=sub,
    )

    # Right axis: mean error_all
    ax2.plot(
        df_sub["session"],
        df_sub["err_all"],
        marker="x",
        linestyle="--",
        linewidth=4,
        color=color,
    )

# Axis labels
ax1.set_xlabel("Session")
ax1.set_ylabel("Compensation")
ax1.set_ylim(0, 10)

ax2.set_ylabel("Mean error (all items)")
# Optionally enforce symmetric limits around zero, e.g.:
# max_abs = np.nanmax(np.abs(df["err_all"]))
# ax2.set_ylim(-max_abs, max_abs)

# Titles / grids
ax1.set_title("Compensation and Mean Value-Recall Error Over Sessions")
ax1.grid(True, alpha=0.3)

# Legend: subjects by color
subject_legend = ax1.legend(
    title="Subject",
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)

# Legend: metrics by line style
metric_lines = [
    Line2D([0], [0], color="black", linestyle="-", marker="o",
           label="Compensation (left y)"),
    Line2D([0], [0], color="black", linestyle="--", marker="x",
           label="Mean error_all (right y)"),
]
ax2.legend(handles=metric_lines, loc="lower right")

plt.tight_layout()
plt.show()

# %%
recall_sess

# %%
# ---------------------------------------------------
# 6. Correlation: Recall Probability vs Compensation per subject
# ---------------------------------------------------

corr_rows = []

for sub in subjects_plot:
    df_sub = df[df["subject"] == sub].sort_values("session")

    if df_sub["compensation"].nunique() > 1:  # need variation
        corr = df_sub["compensation"].corr(df_sub["Recall_Probability"])
    else:
        corr = np.nan

    corr_rows.append({"subject": sub, "corr_comp_recall": corr})

df_corr = pd.DataFrame(corr_rows)
print(df_corr)

# ---------------------------------------------------
# 7. Plot correlations
# ---------------------------------------------------

plt.figure(figsize=(10, 6))
plt.bar(df_corr["subject"], df_corr["corr_comp_recall"], color="skyblue")
plt.axhline(0, color="black", linewidth=1)

plt.xticks(rotation=90)
plt.ylabel("Correlation (Recall Probability vs Compensation)")
plt.title("Per-Subject Correlation Between Recall Probability and Compensation")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# ---------------------------------------------------
# 1. Recall probability per subject *and session*
# ---------------------------------------------------
pres = full_evs.trial_type == "WORD"

recall_sess = (
    full_evs[pres]
    .groupby(["subject", "session"])["recalled"]
    .mean()
    .reset_index(name="Recall_Probability")
)

# ---------------------------------------------------
# 2. Compensation per subject × session
# ---------------------------------------------------
rows = []

for sub in subjects:
    for sess in range(6):
        subset = full_evs[(full_evs.subject == sub) & (full_evs.session == sess)]

        if subset.empty:
            continue

        comp = subset.iloc[0].compensation
        if comp >= 0:
            rows.append({"subject": sub, "session": sess, "compensation": comp})

df_comp = pd.DataFrame(rows).sort_values(["subject", "session"])

# ---------------------------------------------------
# 3. Merge compensation + recall
# ---------------------------------------------------
df = pd.merge(df_comp, recall_sess, on=["subject", "session"], how="inner")

# ---------------------------------------------------
# 4. REMOVE subjects with only 1 session
# ---------------------------------------------------
counts = df.groupby("subject")["session"].nunique()
subjects_keep = counts[counts > 1].index

df = df[df["subject"].isin(subjects_keep)]

print("Subjects kept (≥2 sessions):", list(subjects_keep))

# ---------------------------------------------------
# 5. Plot – twin axes, same color per subject
# ---------------------------------------------------
fig, ax1 = plt.subplots(figsize=(14, 8))
ax2 = ax1.twinx()

subjects_plot = sorted(df["subject"].unique())

# NEW COLOR SCHEME:
colors = plt.cm.rainbow(np.linspace(0, 1, len(subjects_plot)))

for color, sub in zip(colors, subjects_plot):
    df_sub = df[df["subject"] == sub].sort_values("session")

    # Compensation (left axis)
    ax1.plot(
        df_sub["session"],
        df_sub["compensation"],
        marker="o",
        linestyle="-",
        linewidth=4,
        color=color,
        label=sub,
    )

    # Recall prob (right axis)
    ax2.plot(
        df_sub["session"],
        df_sub["Recall_Probability"],
        marker="x",
        linestyle="--",
        linewidth=4,
        color=color,
    )

# Axis labels
ax1.set_xlabel("Session")
ax1.set_ylabel("Compensation")
ax1.set_ylim(0, 10)

ax2.set_ylabel("Recall probability")
ax2.set_ylim(0, 1)

# Titles / grids
ax1.set_title("Compensation and Recall Probability Over Sessions")
ax1.grid(True, alpha=0.3)

# Legend: subjects by color
subject_legend = ax1.legend(title="Subject", bbox_to_anchor=(1.05, 1), loc="upper left")

# Legend: metrics by line style
metric_lines = [
    Line2D([0], [0], color="black", linestyle="-", marker="o", label="Compensation (left y)"),
    Line2D([0], [0], color="black", linestyle="--", marker="x", label="Recall probability (right y)")
]
ax2.legend(handles=metric_lines, loc="lower right")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt



# 1. Keep only WORD events
word_evs = temporal_evs[temporal_evs.trial_type == "WORD"].copy()

# 2. Sort so serial positions are in order
word_evs = word_evs.sort_values(
    ["subject", "session", "trial", "serialpos"]
)

# 3. Loop over subject–session–trial groups
for (sub, sess, trial), df_trial in word_evs.groupby(["subject", "session", "trial"]):

    # pull out data
    df_trial = df_trial.sort_values("serialpos")
    x = df_trial["serialpos"].to_numpy()
    y = df_trial["itemvalue"].to_numpy()

    # determine condition (temporal/random/etc.)
    conds = df_trial["storepointtype"].dropna().unique()
    if len(conds) == 1:
        cond = conds[0]
    elif len(conds) == 0:
        cond = "unknown"
    else:
        cond = "mixed"

    # compute mean
    y_mean = np.mean(y)

    # --- Plot ---
    plt.figure(figsize=(7, 4))

    # main trace
    plt.plot(x, y, marker="o", linewidth=2, label=f"Values")

    # mean line
    plt.axhline(y_mean, color="red", linestyle="--", linewidth=2,
                label=f"Mean = {y_mean:.2f}")
    
    # Shade primacy (first 0–1 positions) in green
    plt.axvspan(0 , 3 - 0.5, color='green', alpha=0.2)  # adjust -0.5 for marker centering

    plt.axvspan(3 - 0.5, 8 - 0.5, color='magenta', alpha=0.2)  # adjust -0.5 for marker centering

    plt.axvspan(8 - 0.5, 13 - 0.5, color='yellow', alpha=0.2)  # adjust -0.5 for marker centering

    # Shade recency (last 3 positions) in red
    # plt.axvspan(15 - 3 - 0.5, 15, color='red', alpha=0.2)


    # formatting
    plt.title(f"{sub} – Session {sess} – Trial {trial} ({cond})")
    plt.xlabel("Serial position")
    plt.ylabel("Item value")
    plt.grid(True, alpha=0.4)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 1. Keep WORD events
word_evs = temporal_evs[temporal_evs.trial_type == "WORD"].copy()

# 2. Sort so serial positions are in order
word_evs = word_evs.sort_values(["subject", "session", "trial", "serialpos"])

# 3. Storage list for mean values
rows = []

# 4. Loop over trials and compute list means
for (sub, sess, trial), df_trial in word_evs.groupby(["subject", "session", "trial"]):
    df_trial = df_trial.sort_values("serialpos")

    y = df_trial["itemvalue"].to_numpy()
    y_mean = np.mean(y)

    # determine condition (temporal/random/etc.)
    conds = df_trial["storepointtype"].dropna().unique()
    if len(conds) == 1:
        cond = conds[0]
    elif len(conds) == 0:
        cond = "unknown"
    else:
        cond = "mixed"

    rows.append({
        "subject": sub,
        "session": sess,
        "trial": trial,
        "mean_value": y_mean,
        "condition": cond,
    })

# Convert to dataframe
df_means = pd.DataFrame(rows)

# %%
plt.figure(figsize=(10, 6))

for cond in df_means["condition"].unique():
    vals = df_means[df_means["condition"] == cond]["mean_value"]
    plt.hist(vals, bins=50, alpha=0.5, label=cond)

plt.xlabel("Mean item value per list")
plt.ylabel("Count")
plt.title("Distribution of List Means by Condition")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 1. Keep WORD events
word_evs = temporal_evs[temporal_evs.trial_type == "WORD"].copy()

# 2. Sort so serial positions are in correct order
word_evs = word_evs.sort_values(["subject", "session", "trial", "serialpos"])

# 3. Storage for results
rows = []

# 4. Loop through lists and compute STD
for (sub, sess, trial), df_trial in word_evs.groupby(["subject", "session", "trial"]):
    df_trial = df_trial.sort_values("serialpos")

    y = df_trial["itemvalue"].to_numpy()
    y_std = np.std(y)

    # determine condition
    conds = df_trial["storepointtype"].dropna().unique()
    if len(conds) == 1:
        cond = conds[0]
    elif len(conds) == 0:
        cond = "unknown"
    else:
        cond = "mixed"

    rows.append({
        "subject": sub,
        "session": sess,
        "trial": trial,
        "std_value": y_std,
        "condition": cond,
    })

# Convert to dataframe
df_std = pd.DataFrame(rows)

# %%
plt.figure(figsize=(10, 6))

for cond in df_std["condition"].unique():
    vals = df_std[df_std["condition"] == cond]["std_value"]
    plt.hist(vals, bins=15, alpha=0.5, label=cond)

plt.xlabel("Standard deviation per list")
plt.ylabel("Count")
plt.title("List Item-Value STD by Condition")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
