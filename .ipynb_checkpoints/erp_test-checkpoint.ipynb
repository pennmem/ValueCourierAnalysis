# %%
# imports
import cmlreaders as cml
import numpy as np
import matplotlib.pyplot as plt
import os
# from ptsa_plot.ptsa_plot.topo import topoplot
import pandas as pd
from scipy.stats import ttest_rel
from scipy.stats import ttest_ind
from mne.stats import bonferroni_correction
from mne.stats import fdr_correction
import os
import cmldask.CMLDask as da
import cmldask
from dask.distributed import wait, as_completed, progress
from functools import partial
from erp import ERPGenerator

# %%
df = cml.get_data_index()
subjects = ["LTP606"]  # or however you collect them
gen = ERPGenerator(subjects, "ValueCourier",
                   dask_args={'job_name': "zrentala_workshop4",
                              'memory_per_job': "16GB",
                              'max_n_jobs': 25,
                              'log_directory': './results/cluster_logs'},
                   create_client=True)

trange = (-800, 1600)
brange = (-250, -50)

gen.compute_subject(
    df,
    subject=subjects[0],
    trange=trange,
    brange=brange,
    channels="Fz",   # regex example; use 'all' or list like ['LA1','LA2']
    sample_rate=2048,
    freq_band=None,                  # no filtering
    hilbert_power=False
)

# 1) Broadband ERP, Fz-like contacts only (regex)
# gen.compute_all_subjects(
#     df,
#     trange=trange,
#     brange=brange,
#     channels="Fz",   # regex example; use 'all' or list like ['LA1','LA2']
#     sample_rate=500,
#     freq_band=None,                  # no filtering
#     hilbert_power=False
# )

# 2) Theta band power (4–8 Hz) over all channels
# gen.compute_all_subjects(
#     df,
#     trange=trange,
#     brange=brange,
#     channels='all',
#     sample_rate=500,
#     freq_band=(4, 8),
#     hilbert_power=True               # -> ERBP (envelope power)
# )

# build a group array and plot channel-mean
group = gen.load_group(subjects, indir="", fname_prefix="erp_subject_")
if group is not None:
    ERPGenerator.plot(group.mean(dim='subject'), trange, label="Group mean (channel-mean)")
# Out:
# Unique port for zrentala is 51618
# {'dashboard_address': ':51618'}
# To view the dashboard, run:
# `ssh -fN zrentala@rhino2.psych.upenn.edu -L 8000:192.168.86.107:39801` in your local computer's terminal (NOT rhino)
# and then navigate to localhost:8000 in your browser
# 4916
# Opening raw data file /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0_clean_raw.fif...
# /usr/global/miniconda/py310_23.1.0-1/envs/workshop/lib/python3.7/site-packages/distributed/node.py:161: UserWarning: Port 51618 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39801 instead
#   f"Port {expected} is already in use.\n"
#     Range : 0 ... 4190207 =      0.000 ...  2046.000 secs
# Ready.
# Opening raw data file /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0_clean_raw-1.fif...
#     Range : 4190208 ... 8380415 =   2046.000 ...  4092.000 secs
# Ready.
# Opening raw data file /protocols/ltp/subjects/LTP606/experiments/ValueCourier/sessions/0/ephys/current_processed/LTP606_session_0_clean_raw-2.fif...
#     Range : 8380416 ... 10821631 =   4092.000 ...  5284.000 secs
# Ready.
# Reading 0 ... 10821631  =      0.000 ...  5284.000 secs...
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 4916 original time points ...
# 0 bad epochs dropped
# 4916
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-b762a368e4f5> in <module>
#      19     sample_rate=2048,
#      20     freq_band=None,                  # no filtering
# ---> 21     hilbert_power=False
#      22 )
#      23
#
# ~/ValueCourierAnalysis/erp.py in compute_subject(self, df, subject, trange, brange, channels, sample_rate, exclude_sessions, freq_band, band_order, hilbert_power, outdir, fname_prefix, event_average)
#     245
#     246             # choose electrodes
# --> 247             eeg = self._select_channels(eeg, channels)  # (event, channel, time)
#     248
#     249             # optional frequency processing
#
# ~/ValueCourierAnalysis/erp.py in _select_channels(eeg, channels)
#     102             keep = [c for c in ch_names if pat.search(c)]
#     103         if len(keep) == 0:
# --> 104             raise ValueError("No channels matched your selection.")
#     105         return eeg.sel(channel=keep)
#     106
#
# ValueError: No channels matched your selection.

# %%
subject ='LTP610'
experiment = 'ValueCourier'
sub_df = df.query('subject == @subject')

# %%
sub_df

# %%
save_timeseries_dict(all_sess_data, "erp_test.pkl")

# %%
all_sess_data = calculate_erp_all_sessions_all_subjects_load(df, subjects, exp, trange, brange, serialpos, rec_type, exclude_list)
all_sess_data

# %%
plot_erp(all_sess_data, trange)
