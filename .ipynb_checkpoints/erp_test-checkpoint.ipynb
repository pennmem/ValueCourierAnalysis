# %%
# imports
import cmlreaders as cml
import numpy as np
import matplotlib.pyplot as plt
import os
# from ptsa_plot.ptsa_plot.topo import topoplot
import pandas as pd
from scipy.stats import ttest_rel
from scipy.stats import ttest_ind
from mne.stats import bonferroni_correction
from mne.stats import fdr_correction
import os
import cmldask.CMLDask as da
import cmldask
from dask.distributed import wait, as_completed, progress
from functools import partial
from erp import ERPGenerator

# %%
df = cml.get_data_index()
subjects = ["LTP606"]  # or however you collect them
gen = ERPGenerator(None, "ValueCourier",
                   dask_args={'job_name': "zrentala_workshop4",
                              'memory_per_job': "16GB",
                              'max_n_jobs': 25,
                              'log_directory': './results/cluster_logs'},
                   create_client=True)

trange = (-800, 1600)
brange = (-250, -50)

# gen.compute_subject(
#     df,
#     subject=subjects[0],
#     trange=trange,
#     brange=brange,
#     channels="A1",   # regex example; use 'all' or list like ['LA1','LA2']
#     sample_rate=2048,
#     freq_band=None,                  # no filtering
#     hilbert_power=False
# )
# Out:
# Unique port for zrentala is 51618
# {'dashboard_address': ':51618'}
# To view the dashboard, run:
# `ssh -fN zrentala@rhino2.psych.upenn.edu -L 8000:192.168.86.107:51618` in your local computer's terminal (NOT rhino)
# and then navigate to localhost:8000 in your browser

# %%
print(gen.subjects)
# Out:
# None

# %%
# gen.compute_all_subjects(
#     df,
#     trange=trange,
#     brange=brange,
#     channels="A1",   # regex example; use 'all' or list like ['LA1','LA2']
#     sample_rate=2400,
#     freq_band=None,                  # no filtering
#     hilbert_power=False
# )

# %%
group = gen.load_group(subjects=['LTP606','LTP607','LTP609','LTP610','LTP612'], indir="results", fname_prefix="erp_ValueCourier_subject_")
# Out:
# saved → results/erp_group.pkl
# ✅ saved group with 5 subjects → results/erp_group.pkl

# %%
# suppose `da` is (channel, time)
ERPGenerator.plot_matrix(
    da, trange=(-800, 1600),
    mode="subplots",
    row_labels=list(da['channel'].values),
    show_aggregate=True, aggregate="mean",  # overlay mean in each subplot? (aggregate is global; for subplots it’s not drawn per-panel)
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-72bd23791dff> in <module>
#       3     da, trange=(-800, 1600),
#       4     mode="subplots",
# ----> 5     row_labels=list(da['channel'].values),
#       6     show_aggregate=True, aggregate="mean",  # overlay mean in each subplot? (aggregate is global; for subplots it’s not drawn per-panel)
#       7 )
#
# TypeError: 'module' object is not subscriptable

# %%
gen.plot_group_subjects(
    trange=(-800, 1600),
    subjects=['LTP606','LTP607','LTP609','LTP610','LTP612'],       # or subjects=None to use gen.subjects
    indir="results",
    fname_prefix="erp_ValueCourier_subject_",
    reduce_over_channels="mean",
    mode="overlay",
    show_group_aggregate=True, group_aggregate="mean",
    group_ci="sem", ci_scale=1.96,               # ~95% CI
    title="ValueCourier: channel-mean per subject (overlayed)",
    legend=True
)

# %%
# build a group array and plot channel-mean

for s in group:
    name = s['subject'].values
    ERPGenerator.plot(s, trange, label=f"{name}")

if group is not None:
    ERPGenerator.plot(group.mean(dim='subject'), trange, label="Group mean (channel-mean)")
